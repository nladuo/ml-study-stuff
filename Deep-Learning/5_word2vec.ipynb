# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.946602
# Nearest to three: contemplation, okay, ox, ddot, bourbaki, soak, manners, spate,
# Nearest to most: alkali, eml, libels, delved, eisner, joss, forked, ephesus,
# Nearest to war: millisecond, provable, labor, supersonic, shameless, amstrad, immaterial, qualifies,
# Nearest to states: esdras, heavenly, waterfront, gollancz, bloomsbury, alain, andromeda, especial,
# Nearest to zero: witty, grease, fixing, buses, abstract, ignore, baker, interstitial,
# Nearest to had: zonker, enthusiasts, microprocessors, illa, committees, eurotunnel, multipart, francois,
# Nearest to eight: branko, corinthians, mahommed, yalta, diarrhea, gram, rp, ratios,
# Nearest to from: wrist, olfactory, authentication, panthers, diplomats, rolf, toshiba, negate,
# Nearest to to: welch, metaphorically, northernmost, calibers, edged, syndicates, balanced, notion,
# Nearest to four: migrating, lender, textiles, aix, endpoints, very, nihonshoki, wipo,
# Nearest to was: tutte, mogul, rosewood, zebulon, acetyl, busman, allegations, benedetto,
# Nearest to after: he, congruent, extending, lulu, heinlein, extreme, domed, ikeda,
# Nearest to some: wishes, burundian, dispatches, hunnish, metropolis, enthroned, estonia, yousef,
# Nearest to will: cannae, crucible, assists, folly, xml, carabiners, saumur, lamb,
# Nearest to all: gretzky, bashing, hypnotist, computes, peptidoglycan, nephites, lucie, hiring,
# Nearest to used: pernoud, abs, horsepower, fencers, fertilizer, risk, famous, constantine,
# Average loss at step 2000: 4.362171
# Average loss at step 4000: 3.865855
# Average loss at step 6000: 3.787265
# Average loss at step 8000: 3.682885
# Average loss at step 10000: 3.617082
# Nearest to three: five, four, eight, six, seven, two, nine, zero,
# Nearest to most: reconcile, alkali, ito, restorer, spencer, numan, euros, ghazni,
# Nearest to war: labor, millisecond, supersonic, provable, pertwee, shameless, flightless, babylon,
# Nearest to states: esdras, heavenly, andromeda, aliyah, rembrandt, jekyll, bloomsbury, waterfront,
# Nearest to zero: eight, nine, five, seven, six, three, four, two,
# Nearest to had: has, have, was, curd, masculism, brink, lobbies, rinnan,
# Nearest to eight: six, nine, four, seven, five, three, zero, two,
# Nearest to from: into, by, phoneme, in, on, with, khagan, rolf,
# Nearest to to: not, northernmost, will, would, syndicates, balanced, metaphorically, centronics,
# Nearest to four: six, eight, three, five, seven, nine, two, zero,
# Nearest to was: is, has, had, were, by, are, sabbatical, taro,
# Nearest to after: before, extending, between, inquisitorial, in, through, when, webs,
# Nearest to some: many, teeth, standards, practitioners, unions, wishes, several, tantamount,
# Nearest to will: may, grudge, to, calendar, would, grosbeak, shafts, honecker,
# Nearest to all: posited, relationships, music, sikhism, hypnotist, impulses, cookbooks, straightforwardly,
# Nearest to used: known, nonpolar, synthase, implemented, nerva, capricorn, fertilizer, followed,
# Average loss at step 12000: 3.607231
# Average loss at step 14000: 3.569068
# Average loss at step 16000: 3.413913
# Average loss at step 18000: 3.455909
# Average loss at step 20000: 3.539029
# Nearest to three: four, five, two, six, seven, eight, zero, nine,
# Nearest to most: more, saltwater, many, reconcile, spencer, some, euros, berliner,
# Nearest to war: provable, labor, millisecond, beatle, visor, bryn, babylon, trismegistus,
# Nearest to states: esdras, heavenly, andromeda, aliyah, rembrandt, stole, fen, jekyll,
# Nearest to zero: five, seven, six, three, four, two, nine, eight,
# Nearest to had: has, have, was, were, masculism, lobbies, took, curd,
# Nearest to eight: nine, seven, six, four, three, five, two, zero,
# Nearest to from: into, in, between, rolf, onion, after, and, with,
# Nearest to to: will, would, clipperton, metaphorically, northernmost, not, welch, peacekeepers,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to was: is, has, had, were, became, does, be, when,
# Nearest to after: before, when, from, during, nguni, into, inquisitorial, appease,
# Nearest to some: many, several, these, teeth, neighboring, other, all, their,
# Nearest to will: may, would, can, to, should, could, grudge, honecker,
# Nearest to all: these, relationships, their, posited, many, some, pallium, hypnotist,
# Nearest to used: known, implemented, horsepower, suspended, rollers, ibis, huns, anchored,
# Average loss at step 22000: 3.501697
# Average loss at step 24000: 3.489077
# Average loss at step 26000: 3.482440
# Average loss at step 28000: 3.477583
# Average loss at step 30000: 3.498079
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to most: more, many, some, very, africans, among, saltwater, spencer,
# Nearest to war: labor, beatle, provable, vapor, visor, millisecond, helmet, prefaces,
# Nearest to states: esdras, heavenly, andromeda, stole, aliyah, rembrandt, nations, mated,
# Nearest to zero: five, eight, four, three, seven, six, nine, two,
# Nearest to had: has, have, was, were, took, lobbies, is, finally,
# Nearest to eight: nine, seven, four, six, five, three, zero, one,
# Nearest to from: into, under, until, on, in, between, implying, pathway,
# Nearest to to: will, would, can, centronics, northernmost, welch, metaphorically, may,
# Nearest to four: five, three, eight, seven, six, nine, two, zero,
# Nearest to was: is, had, were, has, became, been, animated, be,
# Nearest to after: before, during, when, nguni, inquisitorial, for, within, brackets,
# Nearest to some: many, several, these, all, most, their, other, teeth,
# Nearest to will: would, can, may, could, should, must, to, might,
# Nearest to all: these, some, many, kits, any, their, various, relationships,
# Nearest to used: known, written, minsk, implemented, regarded, anchored, called, horsepower,
# Average loss at step 32000: 3.495645
# Average loss at step 34000: 3.491434
# Average loss at step 36000: 3.452471
# Average loss at step 38000: 3.300328
# Average loss at step 40000: 3.422829
# Nearest to three: four, two, six, five, seven, eight, nine, one,
# Nearest to most: more, many, among, very, extremely, some, arrakis, worthwhile,
# Nearest to war: vapor, pacified, labor, elevator, provable, millisecond, prefaces, intercommunal,
# Nearest to states: heavenly, nations, kingdom, stole, esdras, andromeda, mensch, soir,
# Nearest to zero: five, seven, six, eight, nine, four, three, two,
# Nearest to had: has, have, was, since, took, were, finally, semicolon,
# Nearest to eight: nine, seven, four, six, five, three, zero, one,
# Nearest to from: into, nationalized, carbohydrate, khagan, of, in, between, on,
# Nearest to to: clint, metaphorically, skydiving, jennings, snk, episcopacy, will, welch,
# Nearest to four: six, three, eight, five, seven, two, nine, one,
# Nearest to was: is, became, were, had, has, been, did, when,
# Nearest to after: before, during, when, sexagesimal, brackets, appease, nguni, by,
# Nearest to some: many, several, these, any, neighboring, both, numerous, framing,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to all: these, various, both, always, displacing, kits, any, three,
# Nearest to used: known, found, referred, written, regarded, periodicals, considered, anchored,
# Average loss at step 42000: 3.433211
# Average loss at step 44000: 3.451868
# Average loss at step 46000: 3.449585
# Average loss at step 48000: 3.351114
# Average loss at step 50000: 3.379892
# Nearest to three: four, six, seven, two, eight, five, nine, zero,
# Nearest to most: more, among, extremely, very, less, many, spencer, reconcile,
# Nearest to war: vapor, pacified, provable, immaterial, prefaces, visor, beatle, intercommunal,
# Nearest to states: kingdom, nations, stole, soir, esdras, heavenly, andromeda, cities,
# Nearest to zero: six, five, four, seven, eight, two, three, nine,
# Nearest to had: has, have, was, having, since, were, curd, finally,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to from: into, through, nationalized, in, under, until, undergoes, hillary,
# Nearest to to: northernmost, would, may, will, assailants, snk, suitably, can,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to was: is, were, has, be, became, had, been, being,
# Nearest to after: before, when, during, while, sexagesimal, through, for, although,
# Nearest to some: many, several, these, both, numerous, various, those, other,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to all: both, various, each, these, xena, any, none, thumbnail,
# Nearest to used: known, written, referred, available, applied, considered, implemented, regarded,
# Average loss at step 52000: 3.435867
# Average loss at step 54000: 3.426699
# Average loss at step 56000: 3.439732
# Average loss at step 58000: 3.393547
# Average loss at step 60000: 3.393016
# Nearest to three: five, four, six, seven, eight, two, nine, one,
# Nearest to most: more, many, some, use, among, less, courier, arrakis,
# Nearest to war: vapor, visor, provable, battle, innkeeper, millisecond, pacified, coriander,
# Nearest to states: kingdom, nations, soir, stole, esdras, scholars, arab, cities,
# Nearest to zero: five, four, six, seven, eight, three, two, nine,
# Nearest to had: has, have, was, having, were, lobbies, finally, took,
# Nearest to eight: nine, seven, six, four, five, three, one, zero,
# Nearest to from: into, through, nationalized, hillary, by, in, within, onion,
# Nearest to to: would, albuquerque, centronics, welch, must, not, for, will,
# Nearest to four: five, six, seven, eight, three, nine, zero, one,
# Nearest to was: is, became, had, were, when, has, although, be,
# Nearest to after: before, during, when, although, through, by, while, sexagesimal,
# Nearest to some: many, several, these, all, numerous, any, most, various,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to all: some, any, both, various, these, many, always, each,
# Nearest to used: known, written, described, found, called, designed, seen, considered,
# Average loss at step 62000: 3.241195
# Average loss at step 64000: 3.251497
# Average loss at step 66000: 3.400820
# Average loss at step 68000: 3.395191
# Average loss at step 70000: 3.358815
# Nearest to three: six, four, five, two, seven, eight, nine, zero,
# Nearest to most: more, less, many, some, use, highly, extremely, among,
# Nearest to war: vapor, battle, series, provable, intercommunal, latvian, pacified, elevator,
# Nearest to states: kingdom, nations, andromeda, stole, esdras, arab, soir, mensch,
# Nearest to zero: five, six, four, seven, eight, three, two, nine,
# Nearest to had: has, have, was, were, since, having, lobbies, received,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to from: through, into, hillary, rolf, nationalized, before, onto, within,
# Nearest to to: will, would, can, welch, must, centronics, northernmost, warfield,
# Nearest to four: six, five, seven, three, eight, two, zero, nine,
# Nearest to was: is, had, has, were, became, be, when, been,
# Nearest to after: before, during, while, when, sexagesimal, olav, through, without,
# Nearest to some: many, several, all, various, these, both, any, numerous,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to all: some, many, various, any, several, both, every, these,
# Nearest to used: known, written, described, designed, seen, found, referred, applied,
# Average loss at step 72000: 3.369734
# Average loss at step 74000: 3.347808
# Average loss at step 76000: 3.321769
# Average loss at step 78000: 3.350925
# Average loss at step 80000: 3.378134
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to most: more, among, less, many, some, cretaceous, particularly, especially,
# Nearest to war: vapor, battle, latvian, breatharian, provable, logitech, elevator, beatle,
# Nearest to states: kingdom, nations, arab, stole, andromeda, esdras, soir, state,
# Nearest to zero: five, seven, four, six, eight, three, two, nine,
# Nearest to had: have, has, were, was, having, been, took, lobbies,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to from: through, into, nationalized, within, hillary, rolf, before, kilts,
# Nearest to to: will, northernmost, edged, syndicates, must, welch, orientalist, would,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to was: is, were, became, has, had, being, been, although,
# Nearest to after: before, during, when, while, sexagesimal, despite, without, through,
# Nearest to some: many, several, various, any, these, both, numerous, all,
# Nearest to will: would, could, can, should, may, must, might, cannot,
# Nearest to all: many, both, various, every, any, several, some, each,
# Nearest to used: known, referred, written, available, found, described, seen, designed,
# Average loss at step 82000: 3.404872
# Average loss at step 84000: 3.407944
# Average loss at step 86000: 3.388010
# Average loss at step 88000: 3.351488
# Average loss at step 90000: 3.358873
# Nearest to three: four, five, eight, two, seven, six, nine, zero,
# Nearest to most: more, less, some, cretaceous, among, particularly, many, use,
# Nearest to war: vapor, battle, during, potos, wars, pacified, latvian, continental,
# Nearest to states: kingdom, nations, arab, soir, atheists, canada, esdras, stole,
# Nearest to zero: five, seven, eight, six, four, three, nine, u,
# Nearest to had: has, have, was, were, having, finally, since, been,
# Nearest to eight: seven, six, five, nine, four, three, zero, two,
# Nearest to from: through, into, onto, towards, within, nationalized, under, across,
# Nearest to to: northernmost, welch, edged, rabi, phonation, would, syndicates, orientalist,
# Nearest to four: five, seven, three, six, eight, two, nine, one,
# Nearest to was: is, had, became, were, has, been, be, scrat,
# Nearest to after: before, during, when, while, for, despite, until, through,
# Nearest to some: many, several, these, any, numerous, both, all, most,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to all: many, several, both, some, every, these, any, those,
# Nearest to used: known, referred, applied, seen, required, designed, described, found,
# Average loss at step 92000: 3.400401
# Average loss at step 94000: 3.255791
# Average loss at step 96000: 3.354116
# Average loss at step 98000: 3.249419
# Average loss at step 100000: 3.359565
# Nearest to three: five, four, seven, six, eight, two, nine, zero,
# Nearest to most: more, less, especially, particularly, cretaceous, among, worthwhile, bedroom,
# Nearest to war: battle, vapor, pacified, wars, elevator, factbook, hymns, lanthanum,
# Nearest to states: kingdom, nations, arab, atheists, esdras, stole, state, andromeda,
# Nearest to zero: four, five, eight, seven, six, three, two, nine,
# Nearest to had: has, have, was, having, were, edvard, lobbies, since,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to from: through, into, nationalized, in, within, differentials, across, onto,
# Nearest to to: will, could, would, can, must, and, edged, should,
# Nearest to four: six, five, seven, eight, nine, three, zero, two,
# Nearest to was: is, became, were, has, had, been, be, although,
# Nearest to after: before, during, when, despite, without, while, although, until,
# Nearest to some: many, several, these, any, numerous, various, all, their,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to all: many, both, several, these, some, any, every, various,
# Nearest to used: applied, found, known, designed, referred, written, required, performed,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
