# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))

for i in range(0, 100):
    print(words[i])
# Out:
# Data size 17005207
# anarchism
# originated
# as
# a
# term
# of
# abuse
# first
# used
# against
# early
# working
# class
# radicals
# including
# the
# diggers
# of
# the
# english
# revolution
# and
# the
# sans
# culottes
# of
# the
# french
# revolution
# whilst
# the
# term
# is
# still
# used
# in
# a
# pejorative
# way
# to
# describe
# any
# act
# that
# used
# violent
# means
# to
# destroy
# the
# organization
# of
# society
# it
# has
# also
# been
# taken
# up
# as
# a
# positive
# label
# by
# self
# defined
# anarchists
# the
# word
# anarchism
# is
# derived
# from
# the
# greek
# without
# archons
# ruler
# chief
# king
# anarchism
# as
# a
# political
# philosophy
# is
# the
# belief
# that
# rulers
# are
# unnecessary
# and
# should
# be
# abolished
# although
# there
# are
# differing

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-8-01669d5c739a>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.411490
# Nearest to for: gerardus, much, prosperous, thrift, pounding, consequent, sheila, figured,
# Nearest to during: isbn, archive, cameras, wants, gestis, lugdunum, skywalker, animation,
# Nearest to many: hydrogenation, sweeney, devine, rusty, tricycle, mjs, teal, deviation,
# Nearest to state: phosphorus, imbalances, jozef, generous, frontage, telegrams, phosphates, hasse,
# Nearest to this: szczecin, knightly, beet, puppies, vectors, tuileries, bell, sgml,
# Nearest to states: vehicular, andersson, trauma, shiite, tinted, technocrats, swaziland, straightforward,
# Nearest to after: temmu, dysfunction, cautioned, demurrage, suitable, caius, kristian, damin,
# Nearest to over: ear, steadman, khaganate, dreams, mcveigh, tem, license, slab,
# Nearest to or: julian, vue, calcium, powerfully, registries, eurasia, xhtml, spoons,
# Nearest to four: palgrave, prc, searchers, maronite, lansing, grief, fluctuate, reggae,
# Nearest to than: disconnect, eighties, lamorna, cheering, tonnes, pearse, praised, boxed,
# Nearest to nine: trail, zodiac, headquartered, caveats, enclosures, chairmen, artwork, bans,
# Nearest to only: bandmates, agilent, skaro, ascetical, tammy, portfolios, growths, resorts,
# Nearest to first: niv, rtf, turbofans, coincidence, essentially, ammonius, singles, protoscience,
# Nearest to he: mannerisms, waterway, seems, godly, inaccuracies, alpacas, militias, chessboard,
# Nearest to their: rm, shielding, gpo, outfit, et, wayne, gestures, toolbars,
# Average loss at step 2000: 4.365546
# Average loss at step 4000: 3.856243
# Average loss at step 6000: 3.793154
# Average loss at step 8000: 3.691254
# Average loss at step 10000: 3.613150
# Nearest to for: like, laity, from, before, kw, with, in, of,
# Nearest to during: gestis, archive, ericaceae, goncourt, past, wants, cameras, proline,
# Nearest to many: some, hydrogenation, other, mamet, these, weeds, tearing, tricycle,
# Nearest to state: bid, phosphorus, elgin, helm, collection, hindu, official, topic,
# Nearest to this: it, the, szczecin, bell, which, beet, tradition, pacifists,
# Nearest to states: vehicular, swaziland, exports, andersson, trauma, poignant, tinted, svetlana,
# Nearest to after: demurrage, choose, kristian, charting, damin, affluent, temmu, before,
# Nearest to over: steadman, ear, mcveigh, merdeka, gemstone, dred, rosen, final,
# Nearest to or: and, than, rash, hermaphrodite, hog, positives, physik, asturias,
# Nearest to four: six, three, eight, seven, five, two, nine, zero,
# Nearest to than: or, marauders, boxed, whistles, rot, eighties, lamorna, cheering,
# Nearest to nine: eight, seven, five, six, zero, three, four, two,
# Nearest to only: per, falsification, bandmates, lahoud, cub, agilent, so, cluniac,
# Nearest to first: singles, niv, gustloff, rude, same, ashkenazi, aylwin, islamic,
# Nearest to he: it, they, she, who, seems, teos, there, stiff,
# Nearest to their: its, his, ruble, these, monastics, gpo, corps, overtake,
# Average loss at step 12000: 3.601473
# Average loss at step 14000: 3.572281
# Average loss at step 16000: 3.410864
# Average loss at step 18000: 3.457301
# Average loss at step 20000: 3.538144
# Nearest to for: of, in, with, by, from, and, rentals, anticommunist,
# Nearest to during: gestis, archive, at, degraded, ericaceae, past, mauna, when,
# Nearest to many: some, other, several, these, all, mamet, weeds, evatt,
# Nearest to state: bid, official, hindu, telegrams, government, collection, elgin, helm,
# Nearest to this: it, which, the, synonymous, a, any, every, szczecin,
# Nearest to states: vehicular, swaziland, claims, exports, physics, us, pointe, camp,
# Nearest to after: before, when, at, ascribe, affluent, pole, until, into,
# Nearest to over: steadman, ear, dred, merdeka, about, final, mcveigh, gemstone,
# Nearest to or: than, and, azeotrope, with, rash, implies, stepson, musab,
# Nearest to four: six, three, seven, eight, five, two, nine, zero,
# Nearest to than: or, marauders, infertile, emancipation, whistles, steels, eighties, boxed,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to only: actually, per, you, contain, mccarthyism, bandmates, falsification, cub,
# Nearest to first: next, niv, same, converging, navy, second, ashkenazi, singles,
# Nearest to he: it, she, they, who, there, bulbs, addressee, teos,
# Nearest to their: its, his, the, these, her, ruble, monastics, both,
# Average loss at step 22000: 3.502804
# Average loss at step 24000: 3.485309
# Average loss at step 26000: 3.477742
# Average loss at step 28000: 3.478225
# Average loss at step 30000: 3.506626
# Nearest to for: of, with, goncourt, laity, rentals, against, gnostics, in,
# Nearest to during: after, when, in, before, until, archive, degraded, at,
# Nearest to many: some, several, these, other, all, various, most, eisenman,
# Nearest to state: government, bid, elgin, scala, topic, columbia, win, validly,
# Nearest to this: it, which, that, bell, palmas, another, any, the,
# Nearest to states: vehicular, claims, voight, us, physics, pointe, partisans, nations,
# Nearest to after: before, when, during, until, from, following, into, within,
# Nearest to over: merdeka, steadman, mcveigh, sustains, upbeat, into, millimeters, final,
# Nearest to or: and, than, gregg, as, but, azeotrope, rousing, with,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to than: or, infertile, steels, marauders, emancipation, poulsen, much, rot,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to only: actually, relationship, issue, per, eels, you, quoting, resorts,
# Nearest to first: second, next, same, niv, singles, converging, ashkenazi, navy,
# Nearest to he: she, it, they, who, there, never, shamans, but,
# Nearest to their: its, his, the, her, these, our, monastics, some,
# Average loss at step 32000: 3.496065
# Average loss at step 34000: 3.490858
# Average loss at step 36000: 3.455897
# Average loss at step 38000: 3.299752
# Average loss at step 40000: 3.430696
# Nearest to for: in, hepworth, curious, of, sixtus, goncourt, whims, conserve,
# Nearest to during: at, when, after, before, in, on, until, ericaceae,
# Nearest to many: some, several, these, various, all, numerous, wilburys, such,
# Nearest to state: government, bid, topic, scala, elgin, validly, columbia, lewinsky,
# Nearest to this: which, it, that, another, aunts, factorials, the, any,
# Nearest to states: vehicular, kingdom, nations, claims, voight, us, deflected, partisans,
# Nearest to after: before, during, when, within, from, privations, godfather, quake,
# Nearest to over: magnesians, resolve, behind, atchison, millimeters, into, holbach, merdeka,
# Nearest to or: and, than, infertile, contender, a, incur, xiv, henriette,
# Nearest to four: six, three, seven, five, eight, two, nine, one,
# Nearest to than: or, infertile, steels, much, marauders, troika, no, bangladeshi,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to only: actually, it, just, you, generally, correspondents, bandmates, plating,
# Nearest to first: second, next, converging, last, same, ashkenazi, niv, polski,
# Nearest to he: she, it, they, there, who, dylan, later, assimilate,
# Nearest to their: its, his, her, the, our, these, both, any,
# Average loss at step 42000: 3.434700
# Average loss at step 44000: 3.454444
# Average loss at step 46000: 3.443978
# Average loss at step 48000: 3.357221
# Average loss at step 50000: 3.383488
# Nearest to for: abelian, including, sixtus, hasbro, dentist, against, from, gendered,
# Nearest to during: after, at, in, when, before, until, against, through,
# Nearest to many: some, several, these, various, both, those, such, all,
# Nearest to state: bid, government, topic, scotch, scala, columbia, validly, elgin,
# Nearest to this: which, it, the, factorials, he, another, eth, szczecin,
# Nearest to states: kingdom, vehicular, nations, claims, voight, us, hydroelectricity, anemometers,
# Nearest to after: before, when, during, while, within, despite, godfather, from,
# Nearest to over: behind, magnesians, about, resolve, on, nguyen, through, francesco,
# Nearest to or: and, than, mothersbaugh, caius, violent, kellogg, jeter, scalars,
# Nearest to four: six, eight, seven, five, three, nine, two, zero,
# Nearest to than: or, much, infertile, shimazu, marauders, azeotrope, emancipation, bangladeshi,
# Nearest to nine: eight, seven, six, four, three, zero, five, two,
# Nearest to only: actually, electrified, still, retained, mossad, generally, probably, plating,
# Nearest to first: next, second, last, converging, same, third, nineteenth, reinforcements,
# Nearest to he: she, it, they, there, who, dylan, then, this,
# Nearest to their: its, his, her, the, both, our, your, gpo,
# Average loss at step 52000: 3.434755
# Average loss at step 54000: 3.427576
# Average loss at step 56000: 3.439645
# Average loss at step 58000: 3.396202
# Average loss at step 60000: 3.393767
# Nearest to for: of, when, including, laity, defensive, in, conserve, curious,
# Nearest to during: after, in, before, when, until, at, throughout, since,
# Nearest to many: some, several, various, these, such, most, all, other,
# Nearest to state: topic, bid, government, federal, hathaway, columbia, scala, elgin,
# Nearest to this: it, which, that, there, the, nsw, a, eth,
# Nearest to states: nations, kingdom, us, voight, claims, anemometers, rejoice, vehicular,
# Nearest to after: before, during, when, while, despite, godfather, under, within,
# Nearest to over: about, magnesians, behind, through, resolve, roux, into, kann,
# Nearest to or: and, than, but, mothersbaugh, oust, any, hog, vestiges,
# Nearest to four: five, six, eight, seven, three, nine, zero, two,
# Nearest to than: much, or, marauders, but, palate, and, steels, shimazu,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to only: actually, first, still, but, also, all, until, pastures,
# Nearest to first: next, second, last, only, same, converging, reinforcements, third,
# Nearest to he: she, it, they, who, there, soon, we, teos,
# Nearest to their: its, his, her, the, our, your, whose, both,
# Average loss at step 62000: 3.236078
# Average loss at step 64000: 3.257490
# Average loss at step 66000: 3.403549
# Average loss at step 68000: 3.396912
# Average loss at step 70000: 3.360516
# Nearest to for: in, including, of, curious, on, against, abelian, to,
# Nearest to during: after, at, throughout, before, in, until, since, under,
# Nearest to many: some, several, these, various, most, all, such, other,
# Nearest to state: government, topic, bid, scala, scotch, federal, university, bowed,
# Nearest to this: which, it, the, that, another, there, factorials, some,
# Nearest to states: kingdom, nations, claims, voight, us, rejoice, vehicular, anemometers,
# Nearest to after: before, during, when, despite, godfather, while, mig, until,
# Nearest to over: about, magnesians, behind, under, resolve, thicknesses, djbdns, through,
# Nearest to or: and, than, any, while, patten, hydrocarbons, like, rewritable,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to than: or, but, much, steels, palate, gules, marauders, and,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to only: actually, still, elsevier, always, quartic, correspondents, pastures, affect,
# Nearest to first: second, next, last, same, third, original, entire, polski,
# Nearest to he: she, it, they, there, who, soon, never, we,
# Nearest to their: its, his, her, the, your, whose, some, our,
# Average loss at step 72000: 3.372126
# Average loss at step 74000: 3.347958
# Average loss at step 76000: 3.315209
# Average loss at step 78000: 3.354385
# Average loss at step 80000: 3.378159
# Nearest to for: including, conserve, positional, against, korca, curious, after, ais,
# Nearest to during: after, when, before, in, throughout, until, at, under,
# Nearest to many: some, several, these, various, numerous, most, all, both,
# Nearest to state: government, scala, city, columbia, topic, temple, bid, lans,
# Nearest to this: which, it, another, the, factorials, some, szczecin, blackberry,
# Nearest to states: kingdom, us, nations, claims, voight, anemometers, aikido, suggests,
# Nearest to after: before, when, during, despite, while, from, godfather, without,
# Nearest to over: about, magnesians, behind, against, millimeters, under, resolve, waltzes,
# Nearest to or: and, than, while, presuppose, sandbox, oust, reopening, but,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to than: or, much, but, palate, far, azeotrope, shimazu, lecturing,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to only: actually, first, correspondents, elsevier, still, pastures, affect, falcons,
# Nearest to first: second, last, next, third, same, depriving, final, only,
# Nearest to he: she, it, they, there, who, never, we, eventually,
# Nearest to their: its, his, her, your, our, my, both, the,
# Average loss at step 82000: 3.409524
# Average loss at step 84000: 3.410263
# Average loss at step 86000: 3.387633
# Average loss at step 88000: 3.350588
# Average loss at step 90000: 3.367648
# Nearest to for: of, during, against, when, including, without, redeeming, laity,
# Nearest to during: after, in, when, until, before, throughout, at, under,
# Nearest to many: some, several, various, these, numerous, all, most, few,
# Nearest to state: topic, scala, government, city, federal, columbia, lans, temple,
# Nearest to this: it, which, another, the, some, he, factorials, seebeck,
# Nearest to states: kingdom, us, nations, claims, voight, suggests, glued, aikido,
# Nearest to after: before, when, during, while, despite, until, through, godfather,
# Nearest to over: magnesians, about, against, behind, kann, strokes, resolve, under,
# Nearest to or: and, than, arf, amish, shropshire, murat, stepson, but,
# Nearest to four: five, seven, eight, three, six, nine, two, one,
# Nearest to than: or, much, palate, scars, no, vestiges, tiergarten, but,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to only: actually, correspondents, still, falcons, elsevier, lahoud, ebro, valerie,
# Nearest to first: second, next, last, original, ashkenazi, third, entire, current,
# Nearest to he: she, it, they, there, who, later, never, eventually,
# Nearest to their: its, his, her, your, our, both, whose, the,
# Average loss at step 92000: 3.396894
# Average loss at step 94000: 3.251156
# Average loss at step 96000: 3.360164
# Average loss at step 98000: 3.243439
# Average loss at step 100000: 3.359655
# Nearest to for: when, after, curious, while, without, futurians, during, including,
# Nearest to during: after, throughout, in, when, before, at, until, despite,
# Nearest to many: some, several, these, various, numerous, all, few, such,
# Nearest to state: topic, city, government, scala, columbia, antique, county, bid,
# Nearest to this: it, which, another, factorials, the, itself, some, rhodope,
# Nearest to states: nations, kingdom, us, voight, claims, anemometers, aikido, rejoice,
# Nearest to after: before, during, when, despite, without, while, godfather, through,
# Nearest to over: magnesians, thicknesses, against, about, francesco, under, approximately, kann,
# Nearest to or: and, than, though, while, manually, any, ns, arf,
# Nearest to four: six, seven, five, eight, nine, two, three, zero,
# Nearest to than: or, much, palate, guatemalans, decibels, scars, vestiges, steels,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to only: actually, approximately, still, correspondents, developers, horrible, no, moussa,
# Nearest to first: second, last, next, third, final, previous, entire, ashkenazi,
# Nearest to he: she, it, they, there, who, we, never, soon,
# Nearest to their: his, its, her, your, our, the, whose, my,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
