# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [05:29, 95.1KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
# test
int_to_vocab[1000]
# Out:
# 'bbc'

# %%
vocab_to_int['bbc']
# Out:
# 1000

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
threshold = 1e-5

from collections import Counter

word_counts = Counter(int_words)
total_count = len(int_words)
print("total_count:", total_count)
# Out:
# total_count: 16680599

# %%
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# %%
def print_condition(word):
    i = vocab_to_int[word]
    print("word:", word, ",int value:", i, ",freq:", freqs[i], ",p_drop:", p_drop[i])

print_condition("the")
print_condition("a")
print_condition("word")
print_condition("our")
print_condition("will")
print_condition(words[0])
# Out:
# word: the ,int value: 0 ,freq: 0.06363056866243233 ,p_drop: 0.987463765777
# word: a ,int value: 5 ,freq: 0.01953604903516954 ,p_drop: 0.977375362388
# word: word ,int value: 247 ,freq: 0.00034039544982767105 ,p_drop: 0.828601061892
# word: our ,int value: 589 ,freq: 0.0001675599299521558 ,p_drop: 0.75570481066
# word: will ,int value: 96 ,freq: 0.0007529705617885785 ,p_drop: 0.884757943059
# word: anarchism ,int value: 5233 ,freq: 1.8164815304294527e-05 ,p_drop: 0.258033141925

# %%
# drop_threshold = 0.85
import random

train_words = [word for word in int_words if  random.random() < (1 - p_drop[word])] # The final subsampled word list

# %%
print(len(train_words))
# Out:
# 4625621

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0 # 左侧
    stop = idx + R #右侧
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, inputs=embed,
                               labels=labels, num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6371 0.4028 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6208 0.3852 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5054 0.3207 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6030 0.2953 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4837 0.3054 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5351 0.2960 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5585 0.2952 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5588 0.2978 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4812 0.2933 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4279 0.2957 sec/batch
# Nearest to three: frustration, turbo, jamaicans, canopies, enterprise, asymptote, abolish, haunted,
# Nearest to no: laetrile, uml, maximums, bambi, arrests, constans, vasquez, notified,
# Nearest to into: cryobiology, halloween, ashe, bourgeoisie, samaritan, jama, pushed, behaviour,
# Nearest to see: sisterhood, pervading, minutes, kabbalistic, flare, knossos, berries, destinies,
# Nearest to their: ystok, suspends, outshone, bodyline, boineburg, event, faxes, flagpole,
# Nearest to may: cheering, embankments, waitakere, sukhoi, riviera, patriotic, inconsistency, clubs,
# Nearest to in: autobahn, fiefs, wattle, carbides, transliterated, feist, exhausting, enhance,
# Nearest to can: trending, ncos, obscures, singh, tune, skipper, leach, schizophrenic,
# Nearest to shown: jokers, lockheed, bone, intentionalists, presbyterianism, oxidizing, single, hors,
# Nearest to defense: quirky, furnaces, develops, choc, realities, comneni, unnatural, scraping,
# Nearest to active: acquiesce, converters, unanswered, skinned, teau, downgraded, italy, dun,
# Nearest to something: peripherals, kissed, incongruity, cheka, scientology, martens, etch, ipcc,
# Nearest to accepted: ewell, gluconeogenesis, poem, mustard, inhuman, depletion, psychologically, ulein,
# Nearest to writers: mauritians, shockley, salic, rename, doubted, merged, schacht, involved,
# Nearest to test: lid, metro, milkshake, gimlet, tenochtitl, circumcised, ramses, novello,
# Nearest to marriage: experimentally, reclining, sheldrake, intracellular, breech, beulah, intracranial, stark,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4625 0.3012 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3606 0.3060 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3284 0.3743 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2243 0.3661 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1440 0.4108 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1693 0.3430 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0770 0.3706 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0722 0.2984 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0114 0.2985 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9669 0.2963 sec/batch
# Nearest to three: frustration, turbo, enterprise, violation, argued, abolish, haunted, widened,
# Nearest to no: uml, issue, arrests, mostly, laetrile, last, constans, prevalence,
# Nearest to into: cryobiology, commodity, halloween, behaviour, pushed, compatible, disciplinary, marker,
# Nearest to see: minutes, sisterhood, device, records, entity, flare, being, substantial,
# Nearest to their: place, event, outshone, mix, men, directional, ystok, destroyed,
# Nearest to may: able, cheering, some, ranking, prayer, patriotic, sukhoi, climbed,
# Nearest to in: autobahn, fiefs, enhance, wattle, movements, carbides, transliterated, though,
# Nearest to can: unexpected, leach, density, below, skipper, warfare, trending, hoshea,
# Nearest to shown: single, bone, jokers, used, intentionalists, lockheed, scan, presbyterianism,
# Nearest to defense: develops, choc, furnaces, quirky, unnatural, chemical, realities, directions,
# Nearest to active: acquiesce, shows, unanswered, italy, converters, dun, teau, extinction,
# Nearest to something: peripherals, ante, kissed, incongruity, scientology, gok, american, etch,
# Nearest to accepted: ewell, poem, gluconeogenesis, gain, important, inhuman, vision, recreation,
# Nearest to writers: mauritians, involved, merged, understood, salic, cover, expandability, clara,
# Nearest to test: metro, stay, circumcised, tenochtitl, milkshake, lid, competitions, document,
# Nearest to marriage: reclining, experimentally, intracellular, sheldrake, readers, breech, respectively, intracranial,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9329 0.3205 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8941 0.3370 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8728 0.3166 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8800 0.3765 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8127 0.2997 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8357 0.3473 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7783 0.3651 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7912 0.3849 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7852 0.3816 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7872 0.3714 sec/batch
# Nearest to three: frustration, turbo, abolish, enterprise, widened, violation, westward, nationalists,
# Nearest to no: uml, arrests, issue, hedonist, maximums, falling, laetrile, justus,
# Nearest to into: halloween, cryobiology, behaviour, marker, bourgeoisie, pushed, likened, commodity,
# Nearest to see: sisterhood, minutes, entity, flare, pervading, inflected, substantial, records,
# Nearest to their: place, directional, ystok, outshone, event, mix, men, implication,
# Nearest to may: cheering, patriotic, embankments, prayer, able, clubs, climbed, dormant,
# Nearest to in: autobahn, transliterated, wattle, seventeenth, fiefs, exhausting, movements, esl,
# Nearest to can: unexpected, density, skipper, tune, schizophrenic, trending, wedding, leach,
# Nearest to shown: single, bone, lockheed, used, jokers, intentionalists, presbyterianism, nepal,
# Nearest to defense: develops, furnaces, realities, quirky, choc, negroes, unnatural, directions,
# Nearest to active: unanswered, acquiesce, converters, shows, dun, interpreter, skinned, extinction,
# Nearest to something: peripherals, kissed, ante, etch, incongruity, ipcc, scientology, reinhold,
# Nearest to accepted: poem, ewell, gluconeogenesis, gain, psychologically, important, labels, inhuman,
# Nearest to writers: mauritians, merged, involved, clara, warren, cattle, cover, understood,
# Nearest to test: metro, stay, circumcised, lid, competitions, conceived, tenochtitl, milkshake,
# Nearest to marriage: experimentally, reclining, intracellular, sheldrake, readers, stark, breech, intracranial,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7828 0.3979 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7543 0.3596 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7296 0.3414 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6989 0.3681 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7501 0.3316 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6940 0.3548 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7207 0.3943 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7056 0.4006 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6953 0.3866 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6480 0.3816 sec/batch
# Nearest to three: turbo, frustration, westward, excelled, eight, enterprise, abolish, jamaicans,
# Nearest to no: notified, maximums, uml, interconnection, falling, issue, constans, bambi,
# Nearest to into: halloween, bourgeoisie, marker, cryobiology, ashe, behaviour, samaritan, likened,
# Nearest to see: sisterhood, minutes, pervading, entity, flare, rolls, elie, device,
# Nearest to their: ystok, place, directional, chaldean, destroyed, nevsky, outshone, implication,
# Nearest to may: cheering, embankments, patriotic, inconsistency, able, prayer, riviera, ranking,
# Nearest to in: autobahn, wattle, seventeenth, esl, megabyte, exhausting, fiefs, transliterated,
# Nearest to can: unexpected, skipper, tune, schizophrenic, density, misfortunes, simplicius, trending,
# Nearest to shown: single, lockheed, bone, used, presbyterianism, jokers, intentionalists, nominally,
# Nearest to defense: furnaces, develops, quirky, choc, realities, negroes, pacification, comneni,
# Nearest to active: acquiesce, unanswered, converters, teau, skinned, shows, downgraded, interpreter,
# Nearest to something: peripherals, kissed, incongruity, etch, ante, scientology, reinhold, ipcc,
# Nearest to accepted: ewell, poem, gluconeogenesis, important, reminder, labels, vision, mustard,
# Nearest to writers: mauritians, merged, rename, involved, expandability, cattle, warren, clara,
# Nearest to test: metro, novello, circumcised, bekenstein, gimlet, competitions, todd, pardoned,
# Nearest to marriage: experimentally, intracellular, reclining, sheldrake, stark, readers, breech, intracranial,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6815 0.4062 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7132 0.3447 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6220 0.4164 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6441 0.3632 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6539 0.3714 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6306 0.3418 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6161 0.2444 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5383 0.3380 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5073 0.3333 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4925 0.3285 sec/batch
# Nearest to three: turbo, eight, four, frustration, writer, peter, excelled, one,
# Nearest to no: maximums, notified, issue, uml, falling, constans, interconnection, hedonist,
# Nearest to into: halloween, cryobiology, ashe, bourgeoisie, jama, marker, samaritan, behaviour,
# Nearest to see: sisterhood, pervading, minutes, entity, flare, n, damper, elie,
# Nearest to their: ystok, place, destroyed, chaldean, nevsky, directional, detractors, gunn,
# Nearest to may: cheering, embankments, able, inconsistency, prayer, mod, patriotic, riviera,
# Nearest to in: autobahn, esl, wattle, seventeenth, transliterated, megabyte, exhausting, alligator,
# Nearest to can: unexpected, tune, schizophrenic, density, machine, analyze, simplicius, misfortunes,
# Nearest to shown: used, single, lockheed, jokers, presbyterianism, bone, nominally, intentionalists,
# Nearest to defense: choc, furnaces, quirky, realities, pacification, deallocated, develops, ethertype,
# Nearest to active: converters, acquiesce, unanswered, downgraded, tia, interpreter, dun, skinned,
# Nearest to something: peripherals, kissed, incongruity, etch, scientology, vegetarian, purists, ipcc,
# Nearest to accepted: ewell, poem, gluconeogenesis, canonically, important, psychologically, reminder, gain,
# Nearest to writers: mauritians, rename, cover, vases, shockley, warren, merged, expandability,
# Nearest to test: novello, circumcised, metro, mommsen, bekenstein, gimlet, competitions, lid,
# Nearest to marriage: intracellular, reclining, experimentally, sheldrake, readers, intracranial, stark, breech,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4971 0.3312 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5042 0.3233 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4551 0.3375 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5078 0.3548 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4989 0.3414 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5008 0.3275 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4430 0.3259 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4064 0.3232 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4259 0.3238 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4229 0.3339 sec/batch
# Nearest to three: turbo, frustration, equatorial, four, epithets, westward, excelled, six,
# Nearest to no: maximums, uml, thing, demigod, interconnection, constans, notified, issue,
# Nearest to into: halloween, cryobiology, likened, seaweed, ashe, behaviour, samaritan, jama,
# Nearest to see: sisterhood, pervading, minutes, entity, n, damper, flare, knossos,
# Nearest to their: chaldean, ystok, place, directional, detractors, destroyed, event, nevsky,
# Nearest to may: cheering, able, embankments, inconsistency, waitakere, follows, prayer, mod,
# Nearest to in: transliterated, autobahn, wattle, esl, alligator, seventeenth, exhausting, feist,
# Nearest to can: unexpected, schizophrenic, density, typically, analyze, machine, simplicius, bang,
# Nearest to shown: used, single, lockheed, bone, jokers, functions, scan, presbyterianism,
# Nearest to defense: choc, furnaces, pacification, quirky, ulster, revenue, delgado, deallocated,
# Nearest to active: converters, acquiesce, dun, skinned, downgraded, tia, unanswered, interpreter,
# Nearest to something: peripherals, kissed, incongruity, etch, purists, martens, synchronic, scientology,
# Nearest to accepted: ewell, poem, gluconeogenesis, important, canonically, gain, psychologically, marxist,
# Nearest to writers: mauritians, cover, vases, involved, shockley, rename, undifferentiated, velo,
# Nearest to test: novello, circumcised, bekenstein, mommsen, metro, gimlet, todd, competitions,
# Nearest to marriage: reclining, sheldrake, intracellular, experimentally, mother, readers, campaigning, intracranial,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4545 0.3532 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4330 0.3533 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4416 0.4006 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4056 0.3495 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3990 0.3696 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4423 0.3741 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4033 0.3847 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3754 0.3458 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3974 0.3755 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3778 0.4389 sec/batch
# Nearest to three: turbo, one, four, eight, equatorial, six, leverett, frustration,
# Nearest to no: maximums, thing, demigod, uml, me, issue, constans, notified,
# Nearest to into: halloween, likened, seaweed, cryobiology, samaritan, behaviour, marker, bourgeoisie,
# Nearest to see: sisterhood, pervading, n, entity, flare, minutes, damper, tomography,
# Nearest to their: chaldean, ystok, directional, detractors, place, men, concern, bombs,
# Nearest to may: able, cheering, embankments, inconsistency, follows, prayer, mod, waitakere,
# Nearest to in: wattle, transliterated, autobahn, esl, seventeenth, alligator, alcan, undercut,
# Nearest to can: unexpected, teeth, schizophrenic, density, simplicius, analyze, amplitudes, machine,
# Nearest to shown: used, single, bone, camcorder, jokers, lockheed, scan, functions,
# Nearest to defense: choc, pacification, deallocated, naumburg, revenue, quirky, delgado, furnaces,
# Nearest to active: acquiesce, skinned, downgraded, converters, dun, tia, interpreter, unanswered,
# Nearest to something: kissed, peripherals, incongruity, etch, purists, colourless, synchronic, scientology,
# Nearest to accepted: ewell, poem, important, canonically, gluconeogenesis, marxist, psychologically, gain,
# Nearest to writers: mauritians, cover, math, undifferentiated, detectives, involved, vases, velo,
# Nearest to test: mommsen, circumcised, novello, bekenstein, gimlet, competitions, ramses, any,
# Nearest to marriage: sheldrake, reclining, intracellular, mother, experimentally, beulah, campaigning, fables,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3717 0.4413 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4170 0.3750 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3558 0.3474 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3646 0.3661 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4053 0.3644 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3960 0.3662 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3848 0.3773 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3616 0.3702 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3294 0.3803 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3463 0.3846 sec/batch
# Nearest to three: one, six, eight, four, turbo, five, zero, two,
# Nearest to no: issue, demigod, me, thing, maximums, notified, uml, quests,
# Nearest to into: halloween, seaweed, likened, samaritan, cryobiology, bourgeoisie, behaviour, pushed,
# Nearest to see: sisterhood, pervading, entity, flare, tomography, n, being, overs,
# Nearest to their: chaldean, detractors, place, concern, examines, nevsky, castillian, ystok,
# Nearest to may: able, inconsistency, cheering, prayer, embankments, follows, some, waitakere,
# Nearest to in: wattle, esl, transliterated, alligator, seventeenth, alcan, autobahn, extroverted,
# Nearest to can: unexpected, teeth, schizophrenic, analyze, amplitudes, machine, tune, density,
# Nearest to shown: used, single, bone, jokers, camcorder, lockheed, cap, synoptic,
# Nearest to defense: choc, revenue, deallocated, naumburg, pacification, furnaces, willson, delgado,
# Nearest to active: acquiesce, tia, skinned, converters, downgraded, dun, unanswered, interpreter,
# Nearest to something: kissed, peripherals, incongruity, etch, purists, incorrect, synchronic, cheka,
# Nearest to accepted: ewell, poem, important, marxist, canonically, christians, psychologically, gain,
# Nearest to writers: mauritians, cover, math, velo, vases, bois, involved, detectives,
# Nearest to test: circumcised, mommsen, bekenstein, novello, difficulties, competitions, gimlet, any,
# Nearest to marriage: reclining, experimentally, sheldrake, mother, intracellular, fables, beulah, campaigning,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3438 0.3478 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2932 0.3645 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3800 0.3789 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3701 0.3310 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3997 0.3464 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2836 0.3943 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2999 0.3444 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3303 0.3298 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2353 0.3749 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2692 0.3739 sec/batch
# Nearest to three: one, four, two, six, eight, zero, five, turbo,
# Nearest to no: me, demigod, issue, constans, contempt, thing, maximums, notified,
# Nearest to into: halloween, samaritan, likened, cryobiology, seaweed, resonates, pushed, ashe,
# Nearest to see: sisterhood, entity, pervading, n, flare, tomography, overs, elie,
# Nearest to their: chaldean, place, detractors, directional, libation, nevsky, ystok, concern,
# Nearest to may: inconsistency, embankments, prayer, able, follows, cheering, mod, patriotic,
# Nearest to in: wattle, seventeenth, alcan, transliterated, extroverted, esl, autobahn, carbides,
# Nearest to can: unexpected, teeth, amplitudes, analyze, schizophrenic, simplicius, trending, tune,
# Nearest to shown: used, single, bone, jokers, camcorder, abbreviations, synoptic, lockheed,
# Nearest to defense: deallocated, choc, combat, revenue, furnaces, naumburg, pacification, willson,
# Nearest to active: acquiesce, skinned, downgraded, tia, assertive, converters, unanswered, shari,
# Nearest to something: kissed, peripherals, incorrect, etch, incongruity, synchronic, purists, foulke,
# Nearest to accepted: ewell, poem, important, marxist, canonically, christians, gain, inhuman,
# Nearest to writers: mauritians, velo, detectives, cover, bois, involved, etta, math,
# Nearest to test: mommsen, bekenstein, circumcised, novello, competitions, difficulties, steamy, todd,
# Nearest to marriage: reclining, experimentally, sheldrake, mother, campaigning, intracellular, children, functionalist,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3099 0.3782 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3271 0.4824 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3620 0.2705 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2403 0.5733 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2184 0.5635 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2252 0.5398 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2301 0.5627 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2286 0.5807 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2260 0.4628 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1832 24.1292 sec/batch
# Nearest to three: one, four, two, six, eight, five, zero, turbo,
# Nearest to no: me, demigod, issue, maximums, thing, constans, uml, shuja,
# Nearest to into: halloween, samaritan, cryobiology, seaweed, pushed, resonates, hempstead, likened,
# Nearest to see: sisterhood, entity, pervading, flare, overs, tomography, n, cubicle,
# Nearest to their: detractors, chaldean, place, directional, event, nevsky, bombs, destroyed,
# Nearest to may: embankments, prayer, inconsistency, evolves, able, follows, patriotic, mod,
# Nearest to in: transliterated, wattle, alcan, extroverted, esl, undercut, carbides, autobahn,
# Nearest to can: unexpected, teeth, amplitudes, schizophrenic, claw, analyze, trending, density,
# Nearest to shown: used, bone, single, jokers, camcorder, abbreviations, cap, synoptic,
# Nearest to defense: deallocated, choc, combat, corran, pacification, revenue, willson, delgado,
# Nearest to active: acquiesce, skinned, downgraded, converters, unanswered, dun, tia, depredations,
# Nearest to something: kissed, incorrect, purists, peripherals, etch, incongruity, foulke, synchronic,
# Nearest to accepted: ewell, poem, canonically, inhuman, marxist, important, reminder, gain,
# Nearest to writers: mauritians, velo, bois, involved, cover, detectives, etta, math,
# Nearest to test: mommsen, circumcised, bekenstein, competitions, difficulties, novello, todd, macfarquhar,
# Nearest to marriage: reclining, mother, sheldrake, campaigning, experimentally, olympian, children, fables,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2253 0.4917 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2202 0.4759 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2339 0.4522 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1326 0.4568 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1576 0.4555 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1784 0.4594 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1736 0.4508 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1762 0.4531 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2136 0.4553 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1569 0.4529 sec/batch
# Nearest to three: one, four, two, five, eight, six, zero, turbo,
# Nearest to no: demigod, me, thing, contempt, issue, uml, constans, shuja,
# Nearest to into: halloween, samaritan, resonates, seaweed, likened, refineries, furnished, pushed,
# Nearest to see: entity, sisterhood, pervading, cubicle, tomography, flare, provably, overs,
# Nearest to their: detractors, directional, place, event, chaldean, allative, predators, libation,
# Nearest to may: prayer, evolves, embankments, able, inconsistency, mod, example, follows,
# Nearest to in: wattle, transliterated, alcan, extroverted, alligator, autobahn, nota, esl,
# Nearest to can: unexpected, teeth, amplitudes, schizophrenic, snapping, machine, shovel, impermeable,
# Nearest to shown: used, bone, single, cap, camcorder, jokers, abbreviations, oscillators,
# Nearest to defense: choc, combat, deallocated, corran, pacification, revenue, willson, delgado,
# Nearest to active: downgraded, skinned, acquiesce, unanswered, converters, depredations, tia, dun,
# Nearest to something: kissed, incorrect, purists, peripherals, incongruity, etch, synchronic, kael,
# Nearest to accepted: ewell, canonically, poem, important, marxist, reminder, inhuman, standpoints,
# Nearest to writers: mauritians, involved, cover, detectives, velo, bois, math, etta,
# Nearest to test: circumcised, bekenstein, mommsen, competitions, todd, difficulties, carcinogens, macfarquhar,
# Nearest to marriage: reclining, mother, campaigning, sheldrake, experimentally, children, olympian, functionalist,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1843 0.4588 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2200 0.4515 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2036 0.4505 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1471 0.4586 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2052 0.4602 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1781 0.4492 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2059 0.4568 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1655 0.4504 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1272 0.4557 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2035 0.4560 sec/batch
# Nearest to three: one, four, five, two, eight, six, zero, turbo,
# Nearest to no: me, demigod, issue, uml, contempt, thing, notified, hedonist,
# Nearest to into: halloween, resonates, samaritan, likened, refineries, pushed, colloquialism, cryobiology,
# Nearest to see: entity, sisterhood, pervading, flare, provably, cubicle, tomography, n,
# Nearest to their: chaldean, detractors, libation, settlers, event, place, predators, castillian,
# Nearest to may: evolves, prayer, embankments, mod, example, inconsistency, patriotic, able,
# Nearest to in: alcan, transliterated, nota, extroverted, wattle, autobahn, nods, undercut,
# Nearest to can: amplitudes, unexpected, teeth, schizophrenic, snapping, density, trending, obscures,
# Nearest to shown: used, single, bone, camcorder, cap, abbreviations, synoptic, multilinear,
# Nearest to defense: deallocated, choc, combat, revenue, corran, willson, delgado, sepp,
# Nearest to active: acquiesce, downgraded, skinned, unanswered, dun, depredations, victimization, nicolo,
# Nearest to something: kissed, incorrect, peripherals, purists, incongruity, kael, synchronic, cheka,
# Nearest to accepted: ewell, canonically, inhuman, poem, important, reminder, vision, standpoints,
# Nearest to writers: mauritians, involved, cover, detectives, bois, velo, math, inlay,
# Nearest to test: bekenstein, circumcised, mommsen, carcinogens, todd, difficulties, posthuman, steamy,
# Nearest to marriage: reclining, campaigning, experimentally, mother, sheldrake, rolland, children, anthromorphic,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1944 0.4705 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1752 0.4650 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1861 0.4555 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1976 0.4555 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1623 0.4546 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1387 0.4452 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1840 0.4501 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1206 0.4634 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1882 0.4599 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2219 0.5011 sec/batch
# Nearest to three: one, four, two, five, eight, six, zero, seven,
# Nearest to no: me, demigod, constans, issue, thing, notified, contempt, hedonist,
# Nearest to into: samaritan, resonates, pushed, halloween, likened, hempstead, refineries, ashe,
# Nearest to see: entity, pervading, sisterhood, flare, cubicle, politecnico, provably, elie,
# Nearest to their: settlers, chaldean, libation, detractors, castillian, allative, predators, place,
# Nearest to may: presiding, patriotic, evolves, embankments, prayer, nederland, absolutism, kun,
# Nearest to in: transliterated, alcan, was, nota, undercut, wattle, anticommunist, londonderry,
# Nearest to can: unexpected, teeth, amplitudes, schizophrenic, trending, snapping, sov, tune,
# Nearest to shown: used, synoptic, bone, single, cap, jokers, camcorder, abbreviations,
# Nearest to defense: combat, deallocated, choc, corran, sepp, rcr, delgado, revenue,
# Nearest to active: acquiesce, unanswered, skinned, downgraded, victimization, nicolo, depredations, perens,
# Nearest to something: kissed, incorrect, purists, peripherals, cheka, kael, synchronic, scientology,
# Nearest to accepted: ewell, poem, canonically, inhuman, important, marxist, reminder, vision,
# Nearest to writers: mauritians, involved, cover, detectives, bois, witted, velo, etta,
# Nearest to test: bekenstein, circumcised, mommsen, carcinogens, todd, difficulties, posthuman, steamy,
# Nearest to marriage: reclining, experimentally, campaigning, mother, children, anthromorphic, rolland, sheldrake,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2110 0.5553 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1265 0.5134 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1498 0.4926 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1615 0.5168 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0117 0.5113 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1426 0.4909 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1417 0.5227 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1185 0.5285 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1733 0.1546 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1210 0.5107 sec/batch
# Nearest to three: four, two, one, five, zero, six, eight, seven,
# Nearest to no: me, demigod, issue, thing, hedonist, contempt, constans, falling,
# Nearest to into: resonates, pushed, samaritan, refineries, halloween, hempstead, cameraman, over,
# Nearest to see: entity, pervading, sisterhood, provably, flare, cubicle, politecnico, overs,
# Nearest to their: settlers, allative, predators, libation, chaldean, tapp, castillian, detractors,
# Nearest to may: evolves, example, embankments, prayer, mod, kun, nederland, patriotic,
# Nearest to in: wattle, transliterated, autobahn, was, nota, alcan, undercut, the,
# Nearest to can: unexpected, amplitudes, teeth, tune, schizophrenic, sov, rests, ppr,
# Nearest to shown: used, single, synoptic, bone, abbreviations, camcorder, cap, multilinear,
# Nearest to defense: deallocated, combat, choc, corran, rcr, amex, sepp, revenue,
# Nearest to active: skinned, acquiesce, unanswered, downgraded, depredations, antonov, victimization, nicolo,
# Nearest to something: kissed, incorrect, purists, peripherals, cheka, kael, synchronic, premarital,
# Nearest to accepted: ewell, inhuman, canonically, poem, reminder, parapsychology, potencies, important,
# Nearest to writers: mauritians, involved, detectives, cover, novelists, velo, bois, etta,
# Nearest to test: bekenstein, circumcised, todd, mommsen, any, difficulties, carcinogens, steamy,
# Nearest to marriage: reclining, experimentally, children, campaigning, mother, anthromorphic, rolland, sheldrake,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0766 0.6147 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0774 0.5514 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0776 0.4850 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0607 0.4808 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0747 0.4841 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0453 0.4769 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0764 0.4803 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0891 0.3797 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1206 0.3799 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0335 0.3550 sec/batch
# Nearest to three: two, four, one, five, zero, six, eight, seven,
# Nearest to no: me, demigod, constans, thing, hedonist, prevalence, maximums, last,
# Nearest to into: resonates, refineries, pushed, samaritan, hempstead, halloween, cameraman, the,
# Nearest to see: entity, pervading, sisterhood, cubicle, provably, flare, imprecise, resource,
# Nearest to their: allative, settlers, chaldean, predators, libation, detractors, haim, toy,
# Nearest to may: evolves, example, prayer, embankments, nonresident, liver, kun, nederland,
# Nearest to in: the, transliterated, wattle, was, nota, autobahn, alcan, alligator,
# Nearest to can: unexpected, amplitudes, schizophrenic, teeth, density, annealing, ppr, snapping,
# Nearest to shown: used, bone, single, cap, camcorder, multilinear, abbreviations, synoptic,
# Nearest to defense: combat, deallocated, corran, choc, rcr, amex, sepp, deployment,
# Nearest to active: skinned, acquiesce, unanswered, downgraded, depredations, victimization, assortment, tia,
# Nearest to something: kissed, incorrect, peripherals, purists, fallacy, cheka, synchronic, premarital,
# Nearest to accepted: canonically, ewell, reminder, inhuman, poem, parapsychology, potencies, standpoints,
# Nearest to writers: mauritians, involved, novelists, atheists, etta, detectives, cover, velo,
# Nearest to test: bekenstein, todd, circumcised, any, mommsen, carcinogens, difficulties, posthuman,
# Nearest to marriage: reclining, children, campaigning, mother, experimentally, rolland, anthromorphic, sheldrake,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0237 0.3181 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0250 0.3396 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0233 0.3298 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0349 0.3137 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0789 0.3277 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0456 0.3182 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0414 0.3826 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1243 0.3301 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0512 0.3714 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0839 0.4256 sec/batch
# Nearest to three: two, four, one, five, six, zero, eight, seven,
# Nearest to no: demigod, thing, me, prevalence, uml, hedonist, maximums, constans,
# Nearest to into: resonates, cameraman, refineries, samaritan, over, pushed, compatible, halloween,
# Nearest to see: entity, pervading, sisterhood, disambiguation, provably, imprecise, database, resource,
# Nearest to their: allative, predators, chaldean, detractors, keep, libation, astonishing, toy,
# Nearest to may: example, evolves, prayer, mod, embankments, correlates, panpsychism, kun,
# Nearest to in: the, transliterated, carbides, ovulation, nota, autobahn, alcan, wattle,
# Nearest to can: amplitudes, unexpected, density, schizophrenic, shovel, snapping, rests, carbohydrates,
# Nearest to shown: used, single, multilinear, cap, camcorder, bone, abbreviations, synoptic,
# Nearest to defense: combat, deallocated, rcr, choc, sepp, corran, amex, deployment,
# Nearest to active: skinned, acquiesce, unanswered, downgraded, depredations, victimization, assortment, dun,
# Nearest to something: incorrect, kissed, purists, fallacy, peripherals, synchronic, kael, gourd,
# Nearest to accepted: canonically, ewell, parapsychology, reminder, inhuman, potencies, complements, poem,
# Nearest to writers: mauritians, involved, novelists, cover, detectives, bois, etta, natives,
# Nearest to test: bekenstein, circumcised, todd, mommsen, carcinogens, difficulties, any, posthuman,
# Nearest to marriage: reclining, anthromorphic, children, campaigning, mother, rolland, experimentally, vilayet,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0941 0.6098 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0673 0.6234 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1112 0.6105 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0167 0.6239 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0728 0.5917 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0695 0.5931 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0751 0.5486 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0896 0.5459 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0933 0.5563 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0552 0.5294 sec/batch
# Nearest to three: two, four, one, five, six, zero, eight, seven,
# Nearest to no: demigod, me, thing, uml, hedonist, constans, last, flores,
# Nearest to into: resonates, cameraman, samaritan, over, pushed, the, refineries, legion,
# Nearest to see: entity, pervading, disambiguation, abaco, powers, provably, sisterhood, links,
# Nearest to their: allative, settlers, chaldean, predators, libation, unionists, detractors, castillian,
# Nearest to may: example, evolves, presiding, prayer, mod, kun, reconsideration, heal,
# Nearest to in: the, was, nota, transliterated, anticommunist, alcan, wattle, carbides,
# Nearest to can: unexpected, snapping, amplitudes, schizophrenic, rests, shovel, sov, trending,
# Nearest to shown: used, single, multilinear, synoptic, cap, camcorder, abbreviations, bone,
# Nearest to defense: combat, sepp, deallocated, rcr, choc, corran, amex, deployment,
# Nearest to active: skinned, unanswered, acquiesce, downgraded, victimization, depredations, assortment, perens,
# Nearest to something: kissed, incorrect, purists, peripherals, kael, cheka, fallacy, premarital,
# Nearest to accepted: canonically, ewell, parapsychology, inhuman, reminder, poem, gain, potencies,
# Nearest to writers: mauritians, novelists, involved, natives, detectives, cover, bois, births,
# Nearest to test: bekenstein, circumcised, mommsen, todd, carcinogens, posthuman, difficulties, steamy,
# Nearest to marriage: reclining, rolland, children, experimentally, mother, anthromorphic, vilayet, campaigning,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0527 0.5281 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0377 0.5339 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0470 0.5141 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0742 0.5740 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1034 0.5648 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1481 0.5586 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1187 0.5643 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0248 0.5614 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0309 0.5531 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0613 0.5675 sec/batch
# Nearest to three: four, two, one, five, zero, six, eight, seven,
# Nearest to no: demigod, me, hedonist, thing, constans, last, uml, flores,
# Nearest to into: resonates, cameraman, refineries, legion, pushed, nikolai, the, samaritan,
# Nearest to see: entity, pervading, disambiguation, provably, bhutto, external, sisterhood, links,
# Nearest to their: allative, settlers, libation, predators, detractors, tacked, castillian, chaldean,
# Nearest to may: example, evolves, mod, prayer, patriotic, presiding, kun, liver,
# Nearest to in: the, was, wattle, transliterated, anticommunist, alligator, carbides, nota,
# Nearest to can: amplitudes, unexpected, schizophrenic, shovel, rests, snapping, sov, density,
# Nearest to shown: used, multilinear, single, synoptic, cap, camcorder, abbreviations, bone,
# Nearest to defense: combat, sepp, deallocated, rcr, amex, choc, corran, deployment,
# Nearest to active: unanswered, skinned, acquiesce, victimization, downgraded, depredations, antonov, assortment,
# Nearest to something: incorrect, kissed, fallacy, peripherals, purists, cheka, kael, synchronic,
# Nearest to accepted: ewell, canonically, parapsychology, reminder, potencies, inhuman, sibley, poem,
# Nearest to writers: novelists, mauritians, involved, natives, atheists, births, detectives, bois,
# Nearest to test: bekenstein, circumcised, carcinogens, mommsen, difficulties, todd, posthuman, any,
# Nearest to marriage: reclining, children, mother, rolland, experimentally, vilayet, husband, anthromorphic,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9738 0.5541 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0316 0.5281 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0603 0.5613 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0554 0.5645 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0633 0.5616 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0434 0.5300 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9934 0.5690 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9857 0.5611 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0118 0.5784 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9797 0.5597 sec/batch
# Nearest to three: two, four, one, five, six, zero, eight, seven,
# Nearest to no: demigod, me, hedonist, thing, maximums, constans, flores, last,
# Nearest to into: resonates, the, pushed, refineries, cameraman, over, hempstead, colloquialism,
# Nearest to see: entity, pervading, disambiguation, sisterhood, links, provably, rings, imprecise,
# Nearest to their: allative, settlers, predators, chaldean, were, populations, haim, toy,
# Nearest to may: evolves, example, prayer, liver, patriotic, mod, embankments, presiding,
# Nearest to in: was, the, transliterated, vallejo, anticommunist, nota, begins, alligator,
# Nearest to can: amplitudes, schizophrenic, unexpected, rests, sov, snapping, shovel, clotting,
# Nearest to shown: multilinear, used, single, cap, camcorder, abbreviations, bone, synoptic,
# Nearest to defense: combat, sepp, deallocated, rcr, amex, corran, choc, staffing,
# Nearest to active: skinned, unanswered, acquiesce, depredations, downgraded, victimization, influences, assortment,
# Nearest to something: incorrect, kissed, fallacy, peripherals, kael, purists, cheka, synchronic,
# Nearest to accepted: canonically, parapsychology, ewell, reminder, potencies, inhuman, sibley, poem,
# Nearest to writers: novelists, mauritians, involved, natives, births, bois, humanists, atheists,
# Nearest to test: mommsen, circumcised, bekenstein, todd, difficulties, carcinogens, any, posthuman,
# Nearest to marriage: reclining, children, mother, married, vilayet, rolland, husband, anthromorphic,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9725 0.5761 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9331 0.5661 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0527 0.5768 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0301 0.5545 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0036 0.5515 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9837 0.5509 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9257 0.5401 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9820 0.5650 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9008 0.5807 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9944 0.5800 sec/batch
# Nearest to three: four, two, one, five, zero, eight, six, seven,
# Nearest to no: demigod, hedonist, maximums, uml, toku, thing, prevalence, last,
# Nearest to into: the, resonates, refineries, seaweed, colloquialism, over, hempstead, cameraman,
# Nearest to see: entity, disambiguation, pervading, links, provably, rings, imprecise, sisterhood,
# Nearest to their: allative, predators, astonishing, settlers, haim, toy, keep, colts,
# Nearest to may: evolves, example, prayer, presiding, mod, patriotic, liver, mitigated,
# Nearest to in: the, was, wattle, transliterated, rams, of, alligator, autobahn,
# Nearest to can: amplitudes, schizophrenic, unexpected, shovel, rests, snapping, ppr, carbohydrates,
# Nearest to shown: multilinear, used, single, cap, bone, camcorder, abbreviations, synoptic,
# Nearest to defense: combat, sepp, amex, deallocated, rcr, corran, delgado, deployment,
# Nearest to active: skinned, unanswered, depredations, acquiesce, downgraded, volcanoes, victimization, bir,
# Nearest to something: incorrect, kissed, purists, fallacy, peripherals, kael, cheka, synchronic,
# Nearest to accepted: canonically, parapsychology, ewell, potencies, reminder, inhuman, sibley, chisinau,
# Nearest to writers: novelists, mauritians, involved, natives, births, transgender, atheists, humanists,
# Nearest to test: bekenstein, circumcised, mommsen, carcinogens, any, todd, difficulties, posthuman,
# Nearest to marriage: married, children, vilayet, reclining, mother, rolland, husband, anthromorphic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0175 0.5656 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9644 0.4702 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9851 0.4642 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0244 0.4533 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0332 0.4564 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9530 0.4813 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0098 0.4922 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0012 0.4859 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0175 0.4657 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0090 0.4677 sec/batch
# Nearest to three: two, four, one, five, eight, six, zero, seven,
# Nearest to no: demigod, uml, hedonist, toku, deconstructive, thing, maximums, protections,
# Nearest to into: resonates, the, cameraman, over, pushed, refineries, colloquialism, cherry,
# Nearest to see: entity, disambiguation, links, pervading, imprecise, believers, provably, external,
# Nearest to their: allative, predators, settlers, libation, keep, detractors, astonishing, haim,
# Nearest to may: example, evolves, prayer, mod, specify, liver, nonresident, presiding,
# Nearest to in: the, transliterated, was, nota, autobahn, vallejo, wattle, rams,
# Nearest to can: unexpected, amplitudes, rests, snapping, schizophrenic, eases, sov, density,
# Nearest to shown: multilinear, single, camcorder, used, submitted, abbreviations, cap, synoptic,
# Nearest to defense: combat, sepp, deallocated, corran, amex, rcr, choc, delgado,
# Nearest to active: skinned, unanswered, depredations, acquiesce, downgraded, volcanoes, bir, steeper,
# Nearest to something: incorrect, kissed, fallacy, purists, kael, peripherals, cheka, synchronic,
# Nearest to accepted: parapsychology, canonically, potencies, ewell, reminder, pirandello, sibley, aaronic,
# Nearest to writers: novelists, mauritians, involved, births, natives, transgender, atheists, inlay,
# Nearest to test: mommsen, circumcised, bekenstein, carcinogens, posthuman, any, todd, difficulties,
# Nearest to marriage: married, vilayet, children, mother, rolland, reclining, husband, experimentally,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0222 0.4927 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9883 0.4746 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0012 0.4969 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9955 0.4673 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0542 0.4946 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0057 0.5239 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9634 0.4973 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9466 0.4892 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9523 0.4839 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0153 0.4714 sec/batch
# Nearest to three: four, one, two, five, eight, six, zero, seven,
# Nearest to no: demigod, hedonist, toku, deconstructive, thing, last, protections, uml,
# Nearest to into: the, resonates, cameraman, pushed, over, geckos, samaritan, nikolai,
# Nearest to see: entity, links, disambiguation, pervading, external, imprecise, of, provably,
# Nearest to their: settlers, predators, allative, populations, facilitated, were, keep, libation,
# Nearest to may: example, presiding, evolves, prayer, specify, nonresident, patriotic, kun,
# Nearest to in: the, was, transliterated, of, wattle, and, vallejo, to,
# ...
# Nearest to no: toku, deconstructive, hedonist, alveolo, ephemeris, insubstantial, that, prevalence,
# Nearest to into: the, a, in, and, after, by, resonates, then,
# Nearest to see: links, of, disambiguation, external, also, article, list, entity,
# Nearest to their: they, to, were, them, are, and, that, such,
# Nearest to may: example, is, a, calibers, lorids, commentator, clitoral, lasts,
# Nearest to in: the, of, to, a, with, and, is, was,
# Nearest to can: to, abodes, kor, must, surprising, equalizer, snapping, density,
# Nearest to shown: submitted, multilinear, trans, camcorder, single, guybrush, reminded, totleben,
# Nearest to defense: sepp, combat, delgado, rcr, choc, drawbar, deployment, buccaneers,
# Nearest to active: unanswered, volcanoes, skinned, steeper, bir, premiership, support, depredations,
# Nearest to something: fallacy, incorrect, we, purists, kissed, notion, puckett, cheka,
# Nearest to accepted: workstation, canonically, parapsychology, agung, sibley, havenco, chalcedon, pirandello,
# Nearest to writers: novelists, fiction, polymaths, births, natives, authors, humanists, winners,
# Nearest to test: testing, bradman, any, bekenstein, mommsen, pad, wickets, circumcised,
# Nearest to marriage: married, vilayet, mother, children, experimentally, husband, rolland, child,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8126 0.6788 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8668 0.6737 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8626 0.6794 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8466 0.6781 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8571 0.6599 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8839 0.6776 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8427 0.6758 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8286 0.7264 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8725 0.6875 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8988 0.6953 sec/batch
# Nearest to three: four, one, two, five, eight, six, zero, seven,
# Nearest to no: insubstantial, toku, deconstructive, hedonist, alveolo, overturning, ephemeris, myasthenia,
# Nearest to into: the, in, after, a, resonates, by, and, transferred,
# Nearest to see: links, disambiguation, of, external, also, article, entity, list,
# Nearest to their: they, to, were, them, and, own, are, that,
# Nearest to may: example, otherwise, commentator, calibers, nonresident, lorids, a, converter,
# Nearest to in: the, of, with, to, and, a, was, for,
# Nearest to can: to, abodes, kor, must, notoc, snapping, constructivists, mugwort,
# Nearest to shown: submitted, multilinear, trans, reminded, camcorder, guybrush, shows, inhibitory,
# Nearest to defense: sepp, combat, choc, rcr, delgado, deployment, analyses, branches,
# Nearest to active: volcanoes, unanswered, skinned, steeper, premiership, bir, depredations, support,
# Nearest to something: incorrect, fallacy, kissed, purists, we, cheka, berne, notion,
# Nearest to accepted: workstation, canonically, parapsychology, sibley, agung, chalcedon, rarely, indication,
# Nearest to writers: novelists, fiction, polymaths, births, authors, natives, transgender, humanists,
# Nearest to test: testing, bradman, any, bekenstein, mommsen, circumcised, pad, wickets,
# Nearest to marriage: married, vilayet, children, husband, mother, experimentally, rolland, daughters,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8731 0.6944 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8367 0.6868 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8335 0.7273 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8624 0.6658 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9029 0.6944 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8266 0.6788 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9489 0.6900 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9113 0.6988 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8687 0.7189 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8099 0.7096 sec/batch
# Nearest to three: four, two, one, five, six, zero, eight, nine,
# Nearest to no: insubstantial, toku, hedonist, alveolo, deconstructive, overturning, constans, myasthenia,
# Nearest to into: the, a, after, in, resonates, by, nikolai, luthor,
# Nearest to see: links, of, disambiguation, external, also, article, list, entity,
# Nearest to their: they, to, were, them, and, own, assimilate, after,
# Nearest to may: commentator, example, calibers, plunkett, nonresident, lorids, sourceforge, clitoral,
# Nearest to in: the, of, with, to, a, and, was, for,
# Nearest to can: to, kor, abodes, must, notoc, equalizer, constructivists, rests,
# Nearest to shown: submitted, multilinear, trans, guybrush, reminded, camcorder, shows, show,
# Nearest to defense: sepp, combat, branches, choc, maga, rcr, staffing, drawbar,
# Nearest to active: unanswered, volcanoes, skinned, steeper, premiership, bir, depredations, discussions,
# Nearest to something: fallacy, incorrect, kissed, we, purists, cheka, notion, puckett,
# Nearest to accepted: workstation, canonically, parapsychology, agung, havenco, sibley, pirandello, chalcedon,
# Nearest to writers: novelists, fiction, polymaths, births, natives, authors, humanists, science,
# Nearest to test: testing, bradman, any, bekenstein, wickets, mommsen, marpol, labeling,
# Nearest to marriage: married, husband, vilayet, children, experimentally, mother, rolland, daughters,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8176 0.7072 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8451 0.7247 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7839 0.7080 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8669 0.6977 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8600 0.6856 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8833 0.6884 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8532 0.5399 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8360 0.6978 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8003 0.7064 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8817 0.6972 sec/batch
# Nearest to three: four, two, one, five, six, zero, eight, seven,
# Nearest to no: toku, insubstantial, hedonist, alveolo, that, deconstructive, myasthenia, constans,
# Nearest to into: the, a, after, in, by, resonates, and, nikolai,
# Nearest to see: links, external, disambiguation, of, also, article, list, entity,
# Nearest to their: they, to, were, them, and, own, after, assimilate,
# Nearest to may: example, clitoral, lorids, commentator, lasts, plunkett, calibers, benzene,
# Nearest to in: the, of, to, with, a, and, was, this,
# Nearest to can: to, kor, abodes, constructivists, notoc, surprising, mugwort, must,
# Nearest to shown: submitted, multilinear, trans, camcorder, inhibitory, guybrush, reminded, no,
# Nearest to defense: sepp, combat, branches, drawbar, rcr, maga, choc, buccaneers,
# Nearest to active: volcanoes, unanswered, skinned, steeper, premiership, bir, depredations, support,
# Nearest to something: fallacy, incorrect, kissed, purists, cheka, we, notion, berne,
# Nearest to accepted: workstation, parapsychology, canonically, havenco, agung, rarely, sibley, truthful,
# Nearest to writers: novelists, polymaths, fiction, births, natives, authors, humanists, transgender,
# Nearest to test: testing, bradman, any, pad, wickets, mommsen, bekenstein, labeling,
# Nearest to marriage: married, vilayet, mother, experimentally, children, rolland, husband, marry,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8146 0.7006 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8217 0.7361 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7430 0.6925 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8514 0.6984 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8647 0.6859 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8270 0.7507 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8572 0.7478 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7023 0.7123 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8402 0.6972 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7993 0.7383 sec/batch
# Nearest to three: four, two, one, five, six, zero, eight, seven,
# Nearest to no: that, toku, insubstantial, myasthenia, hedonist, deconstructive, alveolo, maximums,
# Nearest to into: the, a, in, after, and, by, then, resonates,
# Nearest to see: links, external, disambiguation, of, also, article, list, meanings,
# Nearest to their: they, to, were, and, them, own, are, it,
# Nearest to may: example, calibers, clitoral, lasts, a, lorids, is, otherwise,
# Nearest to in: the, of, to, with, and, a, was, for,
# Nearest to can: to, surprising, must, notoc, we, constructivists, abodes, cannot,
# Nearest to shown: submitted, multilinear, that, trans, camcorder, no, reminded, inhibitory,
# Nearest to defense: sepp, combat, branches, delgado, choc, rcr, drawbar, analyses,
# Nearest to active: volcanoes, unanswered, skinned, steeper, premiership, bir, support, discussions,
# Nearest to something: fallacy, incorrect, kissed, we, notion, purists, cheka, berne,
# Nearest to accepted: workstation, agung, canonically, havenco, parapsychology, rarely, chalcedon, zygotes,
# Nearest to writers: novelists, polymaths, fiction, births, natives, authors, humanists, transgender,
# Nearest to test: testing, bradman, any, pad, wickets, labeling, marpol, bekenstein,
# Nearest to marriage: married, experimentally, vilayet, mother, marry, husband, rolland, alimony,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8103 0.7584 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8411 0.7187 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8539 0.7586 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8145 0.7427 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7978 0.8294 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8957 0.6965 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8242 0.7291 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8090 0.6884 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8704 0.7169 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8438 0.7795 sec/batch
# Nearest to three: four, two, five, one, six, zero, eight, nine,
# Nearest to no: toku, that, insubstantial, myasthenia, overturning, while, hedonist, alveolo,
# Nearest to into: the, a, in, after, by, and, resonates, then,
# Nearest to see: links, external, of, disambiguation, article, also, list, org,
# Nearest to their: they, to, were, and, own, them, are, it,
# Nearest to may: example, is, a, lorids, calibers, lasts, otherwise, march,
# Nearest to in: the, of, with, to, a, and, is, was,
# Nearest to can: to, surprising, we, must, notoc, constructivists, rests, not,
# Nearest to shown: submitted, multilinear, trans, shows, inhibitory, camcorder, reminded, show,
# Nearest to defense: sepp, combat, delgado, defence, branches, drawbar, choc, maga,
# Nearest to active: volcanoes, unanswered, skinned, premiership, steeper, bir, depredations, support,
# Nearest to something: fallacy, incorrect, notion, kissed, we, cheka, purists, puckett,
# Nearest to accepted: workstation, agung, canonically, rarely, havenco, parapsychology, indication, ucla,
# Nearest to writers: novelists, fiction, polymaths, births, authors, natives, science, transgender,
# Nearest to test: testing, bradman, any, pad, labeling, bekenstein, circumcised, wickets,
# Nearest to marriage: married, mother, experimentally, husband, vilayet, marry, alimony, rolland,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8547 0.7073 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8769 0.7030 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8512 0.7248 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8353 0.7388 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8679 0.7260 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8008 0.6929 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8458 0.7223 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8402 0.7197 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8059 0.7557 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8560 0.7180 sec/batch
# Nearest to three: four, two, five, one, six, eight, zero, nine,
# Nearest to no: insubstantial, toku, myasthenia, that, hedonist, interconnection, deconstructive, alveolo,
# Nearest to into: the, a, after, in, by, and, resonates, approximately,
# Nearest to see: links, of, external, disambiguation, article, also, in, list,
# Nearest to their: they, to, were, own, them, and, after, that,
# Nearest to may: example, is, of, a, nonresident, otherwise, it, lorids,
# Nearest to in: the, of, and, to, with, a, one, is,
# Nearest to can: to, must, notoc, will, from, we, snapping, be,
# Nearest to shown: submitted, multilinear, trans, reminded, shows, show, camcorder, inhibitory,
# Nearest to defense: sepp, branches, combat, drawbar, analyses, delgado, choc, defence,
# Nearest to active: volcanoes, unanswered, premiership, skinned, bir, steeper, support, discussions,
# Nearest to something: fallacy, kissed, incorrect, notion, purists, cheka, we, puckett,
# Nearest to accepted: workstation, canonically, agung, rarely, parapsychology, perissodactyla, sibley, truthful,
# Nearest to writers: novelists, fiction, polymaths, births, authors, natives, humanists, science,
# Nearest to test: testing, bradman, labeling, any, bekenstein, pad, circumcised, mommsen,
# Nearest to marriage: married, experimentally, mother, husband, vilayet, children, alimony, marry,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8897 0.7393 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8020 0.7072 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9609 0.7266 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8950 0.7432 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8829 0.7183 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8180 0.7115 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7699 0.7018 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8431 0.7626 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7600 0.7169 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8467 0.7264 sec/batch
# Nearest to three: four, two, one, five, six, zero, eight, nine,
# Nearest to no: insubstantial, toku, hedonist, alveolo, deconstructive, thoroughbred, myasthenia, constans,
# Nearest to into: the, a, in, by, after, resonates, and, then,
# Nearest to see: links, external, of, disambiguation, article, also, list, in,
# Nearest to their: they, to, were, own, them, and, assimilate, after,
# Nearest to may: example, of, lasts, plunkett, otherwise, is, a, calibers,
# Nearest to in: the, of, with, and, to, a, for, was,
# Nearest to can: to, must, we, will, be, easiest, banana, notoc,
# Nearest to shown: submitted, multilinear, trans, camcorder, show, shows, reminded, guybrush,
# Nearest to defense: sepp, branches, combat, maga, drawbar, analyses, staffing, disfellowshipped,
# Nearest to active: volcanoes, unanswered, skinned, premiership, steeper, bir, discussions, interacted,
# Nearest to something: fallacy, incorrect, kissed, notion, we, puckett, cheka, purists,
# Nearest to accepted: workstation, agung, canonically, parapsychology, ucla, zygotes, havenco, reptiles,
# Nearest to writers: novelists, fiction, polymaths, births, authors, natives, science, humanists,
# Nearest to test: bradman, testing, labeling, wickets, pad, any, bekenstein, circumcised,
# Nearest to marriage: married, experimentally, husband, vilayet, marry, mother, alimony, children,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8979 0.7224 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8224 0.6995 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
