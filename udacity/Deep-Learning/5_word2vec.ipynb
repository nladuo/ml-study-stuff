# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.850136
# Nearest to in: westphalian, slava, cezanne, ely, annotation, automator, tuva, impermanent,
# Nearest to one: honecker, diplomats, berets, cadres, counterpart, defy, remey, bickering,
# Nearest to often: oe, shamash, harmonizing, shui, delaying, flask, tithes, rue,
# Nearest to more: walt, proportionality, doodle, polypeptide, avars, revenge, sheryl, sitter,
# Nearest to many: kernighan, sympathizer, stung, alpina, rescue, peress, earthworms, timbers,
# Nearest to six: stopping, impasse, removable, aino, geotechnical, citizenship, hoist, cbe,
# Nearest to is: stenosis, bodies, stratified, petition, steady, subliminal, greve, halo,
# Nearest to was: ranging, crimson, khaganate, inertial, minutemen, starters, repeats, restorative,
# Nearest to can: vern, sheave, depressants, screening, roger, immunoglobulins, repose, balkh,
# Nearest to some: fta, rationally, horseshoe, calif, vegetable, basenji, lammas, storming,
# Nearest to over: sargon, istrian, junius, antonine, perspectives, associative, triumphed, lacrosse,
# Nearest to their: rolle, ores, bartle, vfa, restorations, lees, tba, apprentice,
# Nearest to that: franconia, claims, pla, cooperstown, headroom, galba, erich, siddeley,
# Nearest to and: bg, proceed, coslet, geller, stones, burkert, harpoon, ballad,
# Nearest to five: fayetteville, macroeconomic, montreal, funniest, amnon, terrified, deceased, outflow,
# Nearest to only: weights, fuelled, catalyse, globalisation, marian, perish, petrus, connexion,
# Average loss at step 2000: 4.368714
# Average loss at step 4000: 3.869622
# Average loss at step 6000: 3.789482
# Average loss at step 8000: 3.686637
# Average loss at step 10000: 3.612522
# Nearest to in: of, on, gbp, from, smashing, with, spouses, walsh,
# Nearest to one: six, seven, two, three, eight, four, five, angiotensin,
# Nearest to often: there, it, sometimes, shamash, tithes, who, delaying, woven,
# Nearest to more: revenge, scholarship, shoe, sheryl, bancroft, avars, walt, vah,
# Nearest to many: some, such, several, all, awry, clash, these, schismatic,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to is: was, are, has, welcoming, prevailing, be, nantes, digitally,
# Nearest to was: is, had, has, were, became, been, by, are,
# Nearest to can: may, would, cannot, should, could, dod, will, dm,
# Nearest to some: many, dickinson, cram, fta, neville, snowmen, storming, harrison,
# Nearest to over: pius, sargon, loos, perspectives, istrian, lacrosse, luxuries, chengdu,
# Nearest to their: his, rolle, its, restorations, elevating, recapture, dominance, ores,
# Nearest to that: franconia, this, equals, it, levitation, which, articulate, archimedean,
# Nearest to and: or, who, american, slovene, in, halpin, s, counterclockwise,
# Nearest to five: six, eight, three, seven, zero, four, nine, two,
# Nearest to only: globalisation, marian, charisma, discontinuation, directs, avraham, superstructure, geddy,
# Average loss at step 12000: 3.607829
# Average loss at step 14000: 3.570704
# Average loss at step 16000: 3.409562
# Average loss at step 18000: 3.454681
# Average loss at step 20000: 3.545415
# Nearest to in: at, on, gbp, for, and, from, with, under,
# Nearest to one: four, two, seven, eight, three, six, five, nine,
# Nearest to often: sometimes, there, also, tithes, usually, commonly, now, vez,
# Nearest to more: revenge, scholarship, less, shoe, very, sheryl, most, derisively,
# Nearest to many: some, several, all, these, other, such, dickinson, awry,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to is: was, are, has, but, be, digitally, androgen, does,
# Nearest to was: is, has, had, were, became, are, been, topological,
# Nearest to can: may, would, could, cannot, will, should, might, must,
# Nearest to some: many, these, dickinson, all, several, neville, other, their,
# Nearest to over: sargon, pius, perspectives, loos, after, gospel, lacrosse, luxuries,
# Nearest to their: his, its, the, her, dominance, some, rolle, these,
# Nearest to that: which, but, franconia, this, articulate, marcion, however, equals,
# Nearest to and: or, while, in, but, artifice, which, patents, dbu,
# Nearest to five: seven, six, eight, four, three, zero, two, nine,
# Nearest to only: charisma, superstructure, retellings, future, witch, markus, it, catalyse,
# Average loss at step 22000: 3.498774
# Average loss at step 24000: 3.491183
# Average loss at step 26000: 3.482995
# Average loss at step 28000: 3.477251
# Average loss at step 30000: 3.502441
# Nearest to in: during, at, on, of, under, and, with, from,
# Nearest to one: seven, four, two, eight, nine, six, five, three,
# Nearest to often: sometimes, commonly, usually, there, also, now, still, vez,
# Nearest to more: less, very, most, scholarship, sheryl, revenge, shoe, pitts,
# Nearest to many: some, several, these, all, such, replaces, kleine, other,
# Nearest to six: four, eight, five, nine, seven, three, zero, two,
# Nearest to is: was, has, are, were, became, had, be, includes,
# Nearest to was: is, were, had, has, became, been, when, jacobian,
# Nearest to can: may, could, would, will, cannot, should, must, might,
# Nearest to some: many, these, several, all, their, dickinson, most, ct,
# Nearest to over: sargon, burying, pius, loos, perspectives, gospel, luxuries, into,
# Nearest to their: its, his, the, her, some, these, human, our,
# Nearest to that: which, but, however, this, what, avignon, because, cy,
# Nearest to and: or, but, in, hansard, bahadur, brent, antarctic, reverted,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to only: march, retellings, directs, charisma, does, witch, beyond, future,
# Average loss at step 32000: 3.500840
# Average loss at step 34000: 3.496066
# Average loss at step 36000: 3.454803
# Average loss at step 38000: 3.301225
# Average loss at step 40000: 3.427293
# Nearest to in: on, from, of, and, at, androgen, for, during,
# Nearest to one: seven, two, six, eight, five, four, three, nine,
# Nearest to often: sometimes, usually, commonly, also, generally, still, now, there,
# Nearest to more: less, most, very, rather, scholarship, greater, so, sheryl,
# Nearest to many: some, several, these, various, both, all, replaces, kleine,
# Nearest to six: five, seven, eight, four, nine, three, two, zero,
# Nearest to is: was, are, has, surpluses, while, androgen, in, prevailing,
# Nearest to was: is, became, has, were, had, been, when, did,
# Nearest to can: may, could, will, would, cannot, should, must, might,
# Nearest to some: many, these, several, any, dickinson, various, all, each,
# Nearest to over: sargon, loud, aeschylus, burying, etymologies, sabrina, pius, attendances,
# Nearest to their: its, his, her, the, them, some, our, these,
# Nearest to that: which, however, this, what, where, but, who, because,
# Nearest to and: or, but, in, halpin, counterclockwise, while, densities, e,
# Nearest to five: six, seven, three, four, eight, nine, zero, two,
# Nearest to only: march, governess, beyond, witch, retellings, does, distorts, directs,
# Average loss at step 42000: 3.436383
# Average loss at step 44000: 3.455748
# Average loss at step 46000: 3.452647
# Average loss at step 48000: 3.353405
# Average loss at step 50000: 3.382155
# Nearest to in: on, from, merkel, of, during, realization, and, throughout,
# Nearest to one: six, two, eight, seven, four, five, nine, three,
# Nearest to often: sometimes, usually, commonly, generally, now, also, still, frequently,
# Nearest to more: less, most, very, longer, sheryl, pitts, rather, scholarship,
# Nearest to many: some, several, these, various, both, most, all, such,
# Nearest to six: eight, seven, four, nine, three, five, zero, two,
# Nearest to is: was, are, has, became, were, while, although, contains,
# Nearest to was: is, were, became, has, had, be, resurrect, by,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to some: many, several, these, various, dickinson, most, other, any,
# Nearest to over: sargon, off, smallest, loud, lacrosse, safed, strathclyde, burying,
# Nearest to their: its, his, her, the, whose, our, breatharian, limnic,
# Nearest to that: which, however, but, what, franconia, horizonte, cataract, jansen,
# Nearest to and: or, but, while, brent, of, in, by, s,
# Nearest to five: four, six, eight, seven, nine, three, zero, two,
# Nearest to only: beyond, governess, retellings, witch, march, mated, first, distorts,
# Average loss at step 52000: 3.437027
# Average loss at step 54000: 3.428198
# Average loss at step 56000: 3.439024
# Average loss at step 58000: 3.396011
# Average loss at step 60000: 3.391642
# Nearest to in: during, within, among, between, throughout, at, of, smashing,
# Nearest to one: seven, eight, four, six, two, nine, three, five,
# Nearest to often: sometimes, usually, commonly, generally, now, also, still, frequently,
# Nearest to more: less, most, very, larger, longer, rather, scholarship, pitts,
# Nearest to many: some, several, various, these, both, such, most, all,
# Nearest to six: eight, four, five, nine, seven, three, two, zero,
# Nearest to is: was, has, are, be, suggests, became, does, dru,
# Nearest to was: is, became, had, were, has, been, jacobian, although,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to some: many, several, these, various, any, most, all, the,
# Nearest to over: sargon, in, about, through, between, smallest, within, into,
# Nearest to their: its, his, her, the, whose, our, these, them,
# Nearest to that: which, what, this, however, franconia, it, because, there,
# Nearest to and: or, but, than, analogues, although, including, gurdjieff, while,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to only: beyond, until, march, first, governess, mated, discontinuation, retellings,
# Average loss at step 62000: 3.243198
# Average loss at step 64000: 3.252498
# Average loss at step 66000: 3.404254
# Average loss at step 68000: 3.395935
# Average loss at step 70000: 3.359623
# Nearest to in: within, during, on, until, merkel, among, for, hackers,
# Nearest to one: six, seven, eight, two, nine, four, five, three,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, still, also,
# Nearest to more: less, most, very, longer, larger, too, rather, pitts,
# Nearest to many: some, several, these, various, all, most, both, such,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to is: was, are, has, be, although, includes, digitally, provides,
# Nearest to was: is, were, had, has, been, became, although, when,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to some: many, several, these, all, various, any, most, their,
# Nearest to over: about, around, smallest, mossad, commuter, stuffing, burying, sargon,
# Nearest to their: its, his, her, the, these, our, some, whose,
# Nearest to that: which, however, what, but, this, horizonte, because, still,
# Nearest to and: or, but, while, planters, which, raman, than, for,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to only: march, never, beyond, retellings, best, still, sparkle, last,
# Average loss at step 72000: 3.375053
# Average loss at step 74000: 3.344765
# Average loss at step 76000: 3.313548
# Average loss at step 78000: 3.353027
# Average loss at step 80000: 3.379153
# Nearest to in: during, on, until, at, within, since, of, throughout,
# Nearest to one: seven, six, eight, two, five, three, nine, four,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, still, typically,
# Nearest to more: less, very, most, rather, larger, longer, too, pitts,
# Nearest to many: some, several, various, these, all, most, numerous, both,
# Nearest to six: eight, five, seven, four, three, nine, zero, two,
# Nearest to is: was, has, are, became, provides, welcoming, prevailing, although,
# Nearest to was: is, were, became, has, had, been, when, although,
# Nearest to can: could, may, will, would, must, cannot, should, might,
# Nearest to some: many, several, these, various, most, any, all, certain,
# Nearest to over: around, about, between, off, donations, within, sargon, mossad,
# Nearest to their: its, his, her, our, your, whose, the, several,
# Nearest to that: which, however, what, shockwave, where, dimmu, this, equals,
# Nearest to and: or, brent, but, while, including, decipherment, overseer, narrator,
# Nearest to five: six, four, eight, seven, nine, three, zero, two,
# Nearest to only: never, best, always, sparkle, march, last, incomprehensible, identical,
# Average loss at step 82000: 3.407008
# Average loss at step 84000: 3.413071
# Average loss at step 86000: 3.389046
# Average loss at step 88000: 3.351853
# Average loss at step 90000: 3.364859
# Nearest to in: during, under, within, with, around, between, of, grapefruit,
# Nearest to one: seven, four, eight, two, six, five, three, nine,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, still, also,
# Nearest to more: less, very, most, rather, longer, larger, too, greater,
# Nearest to many: some, several, these, various, all, numerous, most, certain,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to is: was, has, are, although, be, became, makes, does,
# Nearest to was: is, had, were, became, has, been, be, jacobian,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to some: many, several, these, all, any, most, various, certain,
# Nearest to over: off, around, commuter, within, donations, stuffing, between, mossad,
# Nearest to their: its, his, her, our, your, my, whose, jdk,
# Nearest to that: which, however, what, tedious, shockwave, spur, acceleration, because,
# Nearest to and: or, but, while, including, shakespearean, lincos, hanford, although,
# Nearest to five: seven, eight, four, six, three, nine, two, zero,
# Nearest to only: march, never, bankruptcy, incomprehensible, always, sparkle, approximately, without,
# Average loss at step 92000: 3.402121
# Average loss at step 94000: 3.255397
# Average loss at step 96000: 3.361412
# Average loss at step 98000: 3.240553
# Average loss at step 100000: 3.361948
# Nearest to in: during, within, throughout, under, rouge, until, at, merkel,
# Nearest to one: eight, seven, two, five, four, six, three, nine,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, now, still,
# Nearest to more: less, most, very, larger, rather, longer, greater, too,
# Nearest to many: several, some, various, these, numerous, all, few, certain,
# Nearest to six: four, eight, seven, five, nine, three, zero, two,
# Nearest to is: was, has, became, be, are, provides, makes, had,
# Nearest to was: is, became, has, were, had, been, jacobian, being,
# Nearest to can: may, could, will, must, cannot, should, would, might,
# Nearest to some: many, several, these, any, all, certain, various, most,
# Nearest to over: around, commuter, off, within, donations, stopping, about, stuffing,
# Nearest to their: its, his, her, our, your, the, some, several,
# Nearest to that: which, however, what, tedious, spur, actually, because, this,
# Nearest to and: or, but, while, including, when, however, although, like,
# Nearest to five: eight, four, six, seven, three, nine, zero, two,
# Nearest to only: approximately, never, always, best, march, mated, sparkle, glycol,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW, generate_batch
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    index = 0
    for j in range(span):
        if j != bag_window:
            batch[i, index] = buffer[j]
            index += 1
    labels[i] = buffer[bag_window]
    
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, bag_window=bag_window)
    print('\nwith bag_window = %d' % bag_window)
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# train a CBOW model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
#   loss = tf.reduce_mean(
#     tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
#                                train_labels, num_sampled, vocabulary_size))
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.082495
# Nearest to that: haitians, vor, gohan, tobit, borman, akron, scorn, shanks,
# Nearest to th: forma, formation, commutes, hearth, mik, occupation, informers, fated,
# Nearest to zero: budo, collation, marten, advantages, parodying, inception, depressions, incessantly,
# Nearest to world: leapt, humberto, needed, audiobook, caterpillars, surfer, aegean, airbus,
# Nearest to these: superpowered, grinch, recreations, handicaps, jenny, shuffled, discerning, steam,
# Nearest to an: flood, strengthens, zheng, scranton, casuistry, bloodshed, materiel, addictive,
# Nearest to this: lorenz, mvp, froissart, patagonia, lordship, courtiers, lonsdaleite, delano,
# Nearest to united: microorganism, childress, idempotent, diagnostics, reiner, fracture, seigenthaler, scorched,
# Nearest to can: sons, knockout, wings, qh, bskyb, valera, vrije, goldwyn,
# Nearest to were: carolus, peseta, cimeti, carmen, hawthorne, moorish, motet, aaliyah,
# Nearest to the: rhyme, millennia, sca, drysdale, jagan, tristan, hangout, downgraded,
# Nearest to and: how, petitcodiac, fortran, chogm, aluminum, maximilien, hyginus, ilmarinen,
# Nearest to from: amraam, spaceship, defends, conducted, aaas, mouths, cruising, red,
# Nearest to at: kinsman, bothnian, bar, molecular, internal, biographer, mcdonough, nicholls,
# Nearest to are: lattices, bubonic, purana, northridge, vis, noting, sheffield, heliocentric,
# Nearest to american: ncos, filth, manifestos, bst, steward, relocate, silently, fenced,
# Average loss at step 2000: 4.085025
# Average loss at step 4000: 3.558266
# Average loss at step 6000: 3.386906
# Average loss at step 8000: 3.243543
# Average loss at step 10000: 3.177159
# Nearest to that: which, mwi, this, it, massed, folder, psychoanalyst, vetoed,
# Nearest to th: forma, hearth, occupation, mik, discogs, commutes, formation, abe,
# Nearest to zero: four, five, three, six, eight, nine, seven, two,
# Nearest to world: situations, impressive, simultaneity, symbolism, hesychast, needed, teamed, oscillates,
# Nearest to these: cont, many, some, superpowered, such, funimation, simplifies, members,
# Nearest to an: chevy, mishnaic, musik, casuistry, withdrawn, berners, improvisations, rolled,
# Nearest to this: it, which, that, labonte, boosters, the, nozick, irregular,
# Nearest to united: microorganism, childress, judea, reiner, uncompressed, idempotent, approximation, manukau,
# Nearest to can: may, would, could, will, should, must, might, to,
# Nearest to were: are, was, had, mesoamerican, fanclub, eek, canidae, have,
# Nearest to the: its, their, his, socioeconomic, dynamism, algonquian, sorenson, gerard,
# Nearest to and: or, konya, shuttle, tuesday, content, phobias, niebuhr, tammany,
# Nearest to from: into, after, archivers, kuomintang, between, in, eui, red,
# Nearest to at: in, thc, strived, dizzy, melchior, pdp, na, near,
# Nearest to are: were, have, is, entails, oates, busy, soften, yuan,
# Nearest to american: british, filth, osage, silently, uscis, dehydrated, ncos, sudanese,
# Average loss at step 12000: 3.205639
# Average loss at step 14000: 3.150396
# Average loss at step 16000: 3.173666
# Average loss at step 18000: 3.121972
# Average loss at step 20000: 2.984596
# Nearest to that: which, this, what, bassett, programmers, where, sive, folder,
# Nearest to th: eight, forma, hearth, discogs, six, occupation, zero, multipoint,
# Nearest to zero: six, eight, seven, five, nine, four, three, two,
# Nearest to world: situations, troodos, impressive, windy, ovation, friday, teamed, pinching,
# Nearest to these: some, many, such, those, they, cont, several, simplifies,
# Nearest to an: chevy, musik, delighted, flood, berners, adjoining, preconditions, capitulation,
# Nearest to this: which, it, the, that, any, preparatory, slater, labonte,
# Nearest to united: reiner, villains, approximation, microorganism, city, judea, guerilla, rejection,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to were: are, have, was, had, mesoamerican, those, canidae, be,
# Nearest to the: a, any, their, his, its, this, each, every,
# Nearest to and: or, but, foyle, vistula, than, oi, injective, piggy,
# Nearest to from: into, after, archivers, rufinus, kuomintang, wargame, qa, through,
# Nearest to at: thc, in, during, on, tablet, superintendent, near, within,
# Nearest to are: were, have, is, include, kemp, busy, while, be,
# Nearest to american: british, ncos, nigsberg, bilabial, dulles, african, wicked, filth,
# Average loss at step 22000: 3.072885
# Average loss at step 24000: 3.038596
# Average loss at step 26000: 2.999219
# Average loss at step 28000: 3.031403
# Average loss at step 30000: 3.001539
# Nearest to that: which, however, this, what, bassett, where, kanji, folder,
# Nearest to th: forma, six, zero, hearth, rd, five, zhukov, abe,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to world: situations, palaces, ovation, civilized, pinching, troodos, presidential, friday,
# Nearest to these: such, many, those, some, cont, several, their, they,
# Nearest to an: berners, chevy, flood, mishnaic, chase, delighted, adjoining, confederations,
# Nearest to this: which, it, that, the, laminal, what, boosters, slater,
# Nearest to united: reiner, villains, british, pervading, presumptive, microorganism, rejection, ultimate,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to were: are, was, have, had, those, been, mesoamerican, include,
# Nearest to the: its, their, a, this, dei, his, these, barnstorming,
# Nearest to and: or, but, shuttle, including, visited, tuesday, blackstone, tossing,
# Nearest to from: into, through, after, under, across, shakti, in, wargame,
# Nearest to at: thc, during, in, samara, na, misfortunes, tablet, emmy,
# Nearest to are: were, have, is, include, was, those, includes, uptime,
# Nearest to american: dulles, british, french, osage, ncos, african, bilabial, german,
# Average loss at step 32000: 2.822279
# Average loss at step 34000: 2.950422
# Average loss at step 36000: 2.943031
# Average loss at step 38000: 2.939235
# Average loss at step 40000: 2.930366
# Nearest to that: which, however, staging, this, what, kanji, lys, fourier,
# Nearest to th: four, fourth, operettas, forma, rd, accomplishment, zhukov, eight,
# Nearest to zero: five, six, seven, four, eight, three, nine, two,
# Nearest to world: civilized, situations, pope, troodos, windy, universe, however, shocking,
# Nearest to these: those, such, several, many, some, both, various, different,
# Nearest to an: chevy, flood, berners, delighted, mishnaic, rolled, casuistry, confederations,
# Nearest to this: which, it, boosters, what, entertain, that, emitting, he,
# Nearest to united: city, pervading, reiner, judea, ivanovich, villains, rejection, microorganism,
# Nearest to can: could, may, will, would, must, cannot, might, should,
# Nearest to were: are, have, had, was, been, being, buick, racially,
# Nearest to the: their, its, dei, his, a, your, our, whose,
# Nearest to and: or, while, including, but, elliott, provence, cuauht, eclac,
# Nearest to from: through, into, across, after, qa, during, archivers, clout,
# Nearest to at: thc, during, beowulf, trojan, tablet, from, samara, subconscious,
# Nearest to are: were, include, have, is, approves, including, those, kemp,
# Nearest to american: british, french, dulles, african, irish, islamic, international, australian,
# Average loss at step 42000: 2.954217
# Average loss at step 44000: 2.955592
# Average loss at step 46000: 2.904387
# Average loss at step 48000: 2.863609
# Average loss at step 50000: 2.848823
# Nearest to that: which, what, however, where, bassett, this, kanji, it,
# Nearest to th: rd, fourth, zhukov, second, twentieth, forma, nd, third,
# Nearest to zero: five, eight, seven, four, six, three, nine, two,
# Nearest to world: troodos, universe, pope, situations, pinching, civilized, country, shocking,
# Nearest to these: several, many, those, some, various, such, both, all,
# Nearest to an: berners, chevy, casuistry, mishnaic, musik, rolled, confederations, another,
# Nearest to this: which, it, some, any, another, emitting, boosters, the,
# Nearest to united: pervading, judea, villains, aegean, reiner, promoter, holy, ivanovich,
# Nearest to can: could, may, will, would, cannot, must, might, should,
# Nearest to were: are, have, was, had, include, racially, been, mesoamerican,
# Nearest to the: their, its, a, any, your, dei, this, vander,
# Nearest to and: or, american, but, indecision, including, while, although, tammany,
# Nearest to from: across, during, through, into, rufinus, between, mayr, qa,
# Nearest to at: during, near, thc, efta, samara, in, tablet, within,
# Nearest to are: were, have, is, while, include, be, approves, truffaut,
# Nearest to american: british, french, irish, and, australian, chicanos, jim, german,
# Average loss at step 52000: 2.889067
# Average loss at step 54000: 2.866007
# Average loss at step 56000: 2.857589
# Average loss at step 58000: 2.754715
# Average loss at step 60000: 2.828495
# Nearest to that: which, however, what, dropouts, cyclist, kanji, massed, proclaim,
# Nearest to th: rd, twentieth, second, third, fourth, forma, next, zhukov,
# Nearest to zero: five, seven, six, four, three, nine, eight, two,
# Nearest to world: universe, troodos, country, situations, command, hari, symbolism, masculism,
# Nearest to these: several, many, such, those, various, which, some, they,
# Nearest to an: mishnaic, rolled, chevy, casuistry, confederations, delighted, marija, berners,
# Nearest to this: it, which, another, the, whatever, some, any, each,
# Nearest to united: pervading, reiner, villains, devising, judea, british, neighbouring, presumptive,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to were: are, was, have, had, those, been, be, warrants,
# Nearest to the: their, his, its, this, a, any, our, your,
# Nearest to and: or, but, including, argumentum, although, while, solferino, glycolytic,
# Nearest to from: through, into, in, during, rufinus, across, qa, eleusinian,
# Nearest to at: during, in, thc, near, efta, under, tablet, within,
# Nearest to are: were, is, have, include, foregoing, while, be, kemp,
# Nearest to american: african, australian, british, italian, english, irish, dulles, canadian,
# Average loss at step 62000: 2.830444
# Average loss at step 64000: 2.771769
# Average loss at step 66000: 2.757789
# Average loss at step 68000: 2.713885
# Average loss at step 70000: 2.779278
# Nearest to that: which, what, however, but, this, where, massed, motherboard,
# Nearest to th: rd, twentieth, fourth, tenth, sixth, third, forma, six,
# Nearest to zero: five, six, eight, four, seven, three, nine, two,
# Nearest to world: country, european, troodos, situations, trojan, universe, hari, command,
# Nearest to these: those, several, many, various, they, some, which, doughnut,
# Nearest to an: musik, another, berners, casuistry, marija, rolled, apologists, capitulation,
# Nearest to this: which, it, entertain, chairmen, the, capitalistic, that, some,
# Nearest to united: neighbouring, netherlands, pervading, british, villains, bureau, reiner, aegean,
# Nearest to can: could, may, might, will, cannot, would, should, must,
# Nearest to were: are, was, had, those, have, been, include, warrants,
# Nearest to the: its, their, a, his, any, this, our, lubricant,
# Nearest to and: but, or, including, although, while, however, etc, ze,
# Nearest to from: through, into, across, under, rufinus, during, qa, shakti,
# Nearest to at: near, within, during, thc, on, under, throughout, tablet,
# Nearest to are: were, include, is, have, those, kemp, approves, hellenized,
# Nearest to american: australian, british, canadian, african, english, irish, italian, supercomputing,
# Average loss at step 72000: 2.795591
# Average loss at step 74000: 2.641458
# Average loss at step 76000: 2.800505
# Average loss at step 78000: 2.821510
# Average loss at step 80000: 2.781650
# Nearest to that: which, what, however, this, meany, nevertheless, who, instead,
# Nearest to th: six, tenth, twentieth, sixth, fourth, rd, fifteenth, nd,
# Nearest to zero: six, five, eight, seven, four, three, nine, two,
# Nearest to world: universe, european, command, trojan, windy, floor, palaces, hari,
# Nearest to these: those, several, many, some, examples, which, they, such,
# Nearest to an: casuistry, chevy, rolled, berners, mishnaic, strides, delighted, wessel,
# Nearest to this: which, it, neither, that, another, futures, some, itself,
# Nearest to united: netherlands, reiner, neighbouring, arab, villains, holy, british, aegean,
# Nearest to can: could, will, may, cannot, might, must, would, should,
# Nearest to were: are, was, have, been, had, include, mesoamerican, those,
# Nearest to the: their, its, a, his, aphorism, our, oahu, any,
# Nearest to and: or, including, but, etc, although, which, however, provence,
# Nearest to from: through, across, into, qa, during, in, wargame, rufinus,
# Nearest to at: during, near, thc, in, within, efta, samara, under,
# Nearest to are: were, have, is, include, although, approves, fulda, exist,
# Nearest to american: australian, british, african, italian, canadian, german, irish, french,
# Average loss at step 82000: 2.667683
# Average loss at step 84000: 2.769249
# Average loss at step 86000: 2.731847
# Average loss at step 88000: 2.752989
# Average loss at step 90000: 2.732085
# Nearest to that: which, what, however, this, psychoanalyst, meany, permafrost, knowledgeable,
# Nearest to th: fourth, five, sixth, six, fifteenth, tenth, four, zero,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to world: country, floor, universe, situations, windy, command, trojan, hari,
# Nearest to these: those, such, several, examples, many, some, borrowers, various,
# Nearest to an: berners, chevy, rolled, illegally, casuistry, another, mishnaic, capitulation,
# Nearest to this: which, it, each, some, the, neither, another, that,
# Nearest to united: netherlands, neighbouring, british, border, villains, benedictines, reiner, frankish,
# Nearest to can: could, will, might, should, must, may, cannot, would,
# Nearest to were: are, had, was, have, those, been, included, remained,
# Nearest to the: its, his, their, this, a, our, any, your,
# Nearest to and: or, including, although, etc, but, while, yorkist, shaka,
# Nearest to from: across, through, into, during, including, in, qa, toward,
# Nearest to at: near, during, in, serapeum, within, veneer, under, efta,
# Nearest to are: were, is, include, have, exist, including, approves, fulda,
# Nearest to american: australian, british, african, canadian, french, italian, indian, irish,
# Average loss at step 92000: 2.671140
# Average loss at step 94000: 2.720046
# Average loss at step 96000: 2.699886
# Average loss at step 98000: 2.361498
# Average loss at step 100000: 2.406325
# Nearest to that: which, however, what, unless, thz, whom, nevertheless, factsheet,
# Nearest to th: fourth, tenth, sixth, nineteenth, fifth, rd, fifteenth, nd,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to world: universe, trojan, country, floor, european, iterating, situations, hari,
# Nearest to these: such, those, several, many, some, certain, various, borrowers,
# Nearest to an: chevy, rolled, delighted, flood, berners, peano, strides, marija,
# Nearest to this: which, it, some, each, another, any, his, neither,
# Nearest to united: netherlands, neighbouring, city, benedictines, ivanovich, judea, beginning, villains,
# Nearest to can: cannot, could, will, might, must, should, may, would,
# Nearest to were: are, have, include, was, had, been, be, those,
# Nearest to the: his, their, its, her, our, this, bundles, barnstorming,
# Nearest to and: or, but, etc, including, though, ze, tristar, festive,
# Nearest to from: across, through, under, into, restorative, including, during, via,
# Nearest to at: near, during, in, veneer, after, around, within, serapeum,
# Nearest to are: were, include, have, is, those, hellenized, exist, kemp,
# Nearest to american: australian, canadian, british, english, italian, german, russian, s,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
